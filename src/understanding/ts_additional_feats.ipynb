# %% [markdown]
# We use the imdb api (see [documentation](https://imdbapi.dev/))in order to retrieve some basic informations about the titles represented in the time series dataset.

# %%
import requests
import csv
from pathlib import Path
from itertools import batched
from tqdm import tqdm

# %%
data_dir = Path("../../data")
results_dir = Path("../../results")
data_path = data_dir / 'imdb_ts.csv'

# %%
base_url = 'https://api.imdbapi.dev/'
endpoint = "titles/"

# %%
title_id = 'tt0062622'

# %% [markdown]
# ## Example with one record

# %%
response = requests.get(base_url + endpoint + title_id)
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'id': 'tt0062622',
#  'type': 'movie',
#  'primaryTitle': '2001: A Space Odyssey',
#  'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNjU0NDFkMTQtZWY5OS00MmZhLTg3Y2QtZmJhMzMzMWYyYjc2XkEyXkFqcGc@._V1_.jpg',
#   'width': 1380,
#   'height': 2044},
#  'startYear': 1968,
#  'runtimeSeconds': 8940,
#  'genres': ['Adventure', 'Sci-Fi'],
#  'rating': {'aggregateRating': 8.3, 'voteCount': 758947},
#  'metacritic': {'score': 84, 'reviewCount': 25},
#  'plot': 'When a mysterious artifact is uncovered on the Moon, a spacecraft manned by two humans and one supercomputer is sent to Jupiter to find its origins.',
#  'originCountries': [{'code': 'GB', 'name': 'United Kingdom'},
#   {'code': 'US', 'name': 'United States'}],
#  'spokenLanguages': [{'code': 'eng', 'name': 'English'},
#   {'code': 'rus', 'name': 'Russian'},
#   {'code': 'fra', 'name': 'French'}]}

# %%
movie = dict(
    id=title_id,
    title=data.get('primaryTitle'),
    startYear=data.get('startYear'),
    runtimeMinutes=round(data.get('runtimeSeconds') / 60),
    numVotes=data.get('rating', {}).get('voteCount'),
    countryOfOrigin=','.join(country.get('code', '') for country in data.get('originCountries', []))
)

# %%
movie
# Out:
# {'id': 'tt0062622',
#  'title': '2001: A Space Odyssey',
#  'startYear': 1968,
#  'runtimeMinutes': 149,
#  'numVotes': 758947,
#  'countryOfOrigin': 'GB,US'}

# %% [markdown]
# It is also possible to get multiple (up to 10) records at the same time.

# %%
ids = ['tt0062622','tt0064816']
response = requests.get(base_url + 'titles:batchGet?titleIds=' + '&titleIds='.join(ids))

# %%
response.status_code
response.json()
# Out:
# {'titles': [{'id': 'tt0062622',
#    'type': 'movie',
#    'primaryTitle': '2001: A Space Odyssey',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNjU0NDFkMTQtZWY5OS00MmZhLTg3Y2QtZmJhMzMzMWYyYjc2XkEyXkFqcGc@._V1_.jpg',
#     'width': 1380,
#     'height': 2044},
#    'startYear': 1968,
#    'runtimeSeconds': 8940,
#    'genres': ['Adventure', 'Sci-Fi'],
#    'rating': {'aggregateRating': 8.3, 'voteCount': 758947},
#    'metacritic': {'score': 84, 'reviewCount': 25},
#    'plot': 'When a mysterious artifact is uncovered on the Moon, a spacecraft manned by two humans and one supercomputer is sent to Jupiter to find its origins.',
#    'originCountries': [{'code': 'GB', 'name': 'United Kingdom'},
#     {'code': 'US', 'name': 'United States'}],
#    'spokenLanguages': [{'code': 'eng', 'name': 'English'},
#     {'code': 'rus', 'name': 'Russian'},
#     {'code': 'fra', 'name': 'French'}]},
#   {'id': 'tt0064816',
#    'type': 'movie',
#    'primaryTitle': 'The Swimming Pool',
#    'originalTitle': 'La piscine',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZDliNGUyYTMtZWM5OS00ZmQ1LTg5NGItM2I4YTg0N2E0YWQwXkEyXkFqcGc@._V1_.jpg',
#     'width': 1400,
#     'height': 2125},
#    'startYear': 1969,
#    'runtimeSeconds': 7320,
#    'genres': ['Crime', 'Drama', 'Romance'],
#    'rating': {'aggregateRating': 7.1, 'voteCount': 15308},
#    'metacritic': {'score': 76, 'reviewCount': 9},
#    'plot': 'Jean-Paul and Marianne spend lazy holidays at their villa in idyllic Southern France. However when Harry and his attractive young daughter Penelope show up, the dreamy summer days are suddenly filled with unspoken tension and jealousy.',
#    'originCountries': [{'code': 'FR', 'name': 'France'},
#     {'code': 'IT', 'name': 'Italy'}],
#    'spokenLanguages': [{'code': 'fra', 'name': 'French'},
#     {'code': 'eng', 'name': 'English'}]}]}

# %% [markdown]
# Also we query for informations relative to awards and nominations. In this case we only check if the json of the response has some content in order to determine if the title was awarded nominations or awards.

# %%
response = requests.get(base_url + endpoint + title_id + '/awardNominations')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'stats': {'nominationCount': 14, 'winCount': 18},
#  'awardNominations': [{'nominees': [{'id': 'nm0706937',
#      'displayName': 'Douglas Rain',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOGRlNDUxNDAtY2YwMS00N2YyLTk4OGEtZGZjZDJjMzg3Y2NhXkEyXkFqcGc@._V1_.jpg',
#       'width': 658,
#       'height': 819},
#      'birthDate': {'year': 1928, 'month': 5, 'day': 9},
#      'deathDate': {'year': 2018, 'month': 11, 'day': 11}}],
#    'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 2024,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Character',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2024,
#    'text': 'Saturn Award',
#    'category': 'Best Film Home Media Collection Release'},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}}],
#    'event': {'id': 'ev0001001', 'name': 'Kinema Junpo Awards'},
#    'year': 1969,
#    'text': 'Kinema Junpo Award',
#    'category': 'Best Foreign Language Film'},
#   {'nominees': [{'id': 'nm0006154',
#      'displayName': 'Aram Khachaturyan',
#      'birthDate': {'year': 1903, 'month': 6, 'day': 6},
#      'deathDate': {'year': 1978, 'month': 5, 'day': 1}},
#     {'id': 'nm0509893',
#      'displayName': 'György Ligeti',
#      'birthDate': {'year': 1923, 'month': 5, 'day': 28},
#      'deathDate': {'year': 2006, 'month': 6, 'day': 11}},
#     {'id': 'nm0006310',
#      'displayName': 'Johann Strauss',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMjJiMjBkYjUtNTAyOC00N2ZjLWIyODEtYzA2ZTgwNDAxZWJmXkEyXkFqcGc@._V1_.jpg',
#       'width': 851,
#       'height': 1200},
#      'birthDate': {'year': 1825, 'month': 10, 'day': 25},
#      'deathDate': {'year': 1899, 'month': 6, 'day': 3}},
#     {'id': 'nm0006309',
#      'displayName': 'Richard Strauss',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BM2IxY2NhMzAtYWM2YS00Y2MzLTk3NzEtYWY1NGZkZTliNTMzXkEyXkFqcGc@._V1_.jpg',
#       'width': 1152,
#       'height': 1709},
#      'birthDate': {'year': 1864, 'month': 6, 'day': 11},
#      'deathDate': {'year': 1949, 'month': 9, 'day': 8}}],
#    'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 2022,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Score',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}},
#     {'id': 'nm0002009',
#      'displayName': 'Arthur C. Clarke',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#       'width': 1200,
#       'height': 1270},
#      'birthDate': {'year': 1917, 'month': 12, 'day': 16},
#      'deathDate': {'year': 2008, 'month': 3, 'day': 19}}],
#    'event': {'id': 'ev0000712', 'name': "Writers' Guild of Great Britain"},
#    'year': 1969,
#    'text': "Writers' Guild of Great Britain Award",
#    'category': 'Best British Original Screenplay'},
#   {'event': {'id': 'ev0002419',
#     'name': 'Turkish Film Critics Association (SIYAD) Awards'},
#    'year': 1974,
#    'text': 'SIYAD Award',
#    'category': 'Best Foreign Film'},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2019,
#    'text': 'Saturn Award',
#    'category': 'Best DVD/Blu-Ray Classic Film Release',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}}],
#    'event': {'id': 'ev0002340', 'name': 'Jules Verne Awards'},
#    'year': 2008,
#    'text': 'Jules Verne Légendaire Award',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2015,
#    'text': 'Saturn Award',
#    'category': 'Best DVD/Blu-Ray Collection'},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2008,
#    'text': 'Saturn Award',
#    'category': 'Best DVD Collection'},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}}],
#    'event': {'id': 'ev0000450', 'name': 'Moscow International Film Festival'},
#    'year': 1969,
#    'text': 'Golden Prize',
#    'category': 'Best Feature Film'},
#   {'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 1997,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Motion Picture',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0005910',
#      'displayName': 'Geoffrey Unsworth',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZTkwNWI5ODAtYmFkYy00NzZkLTkzODUtODQxZGFkNDNkOTFmXkEyXkFqcGc@._V1_.jpg',
#       'width': 444,
#       'height': 480},
#      'birthDate': {'year': 1914, 'month': 5, 'day': 26},
#      'deathDate': {'year': 1978, 'month': 10, 'day': 28}}],
#    'event': {'id': 'ev0000471',
#     'name': 'National Society of Film Critics Awards, USA'},
#    'year': 1969,
#    'text': 'NSFC Award',
#    'category': 'Best Cinematography',
#    'winnerRank': 3},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}},
#     {'id': 'nm0002009',
#      'displayName': 'Arthur C. Clarke',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#       'width': 1200,
#       'height': 1270},
#      'birthDate': {'year': 1917, 'month': 12, 'day': 16},
#      'deathDate': {'year': 2008, 'month': 3, 'day': 19}}],
#    'event': {'id': 'ev0000335', 'name': 'Hugo Awards'},
#    'year': 1969,
#    'text': 'Hugo',
#    'category': 'Best Dramatic Presentation',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2012,
#    'text': 'Saturn Award',
#    'category': 'Best DVD Collection',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000464', 'name': 'National Board of Review, USA'},
#    'year': 1969,
#    'text': 'NBR Award',
#    'category': 'Top Ten Films',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000468',
#     'name': 'National Film Preservation Board, USA'},
#    'year': 1991,
#    'text': 'National Film Registry',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000394', 'name': 'Laurel Awards'},
#    'year': 1968,
#    'text': 'Golden Laurel',
#    'category': 'Road Show',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'birthDate': {'year': 1928, 'month': 7, 'day': 26},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 7}}],
#    'event': {'id': 'ev0000123', 'name': 'BAFTA Awards'},
#    'year': 1969,
#    'text': 'UN Award'},
#   {'nominees': [{'id': 'nm0753160',
#      'displayName': 'Winston Ryder',
#      'birthDate': {'year': 1915, 'month': 3, 'day': 25},
#      'deathDate': {'year': 1999, 'month': 3, 'day': 24}}],
#    'event': {'id': 'ev0000123', 'name': 'BAFTA Awards'},
#    'year': 1969,
#    'text': 'BAFTA Film Award',
#    'category': 'Best Sound Track',
#    'isWinner': True,
#    'winnerRank': 1}],
#  'nextPageToken': 'eyJpZCI6ImFuMDE0OTcyNyJ9'}

# %% [markdown]
# ## And now the rest

# %%
title_ids = []

with open(data_path) as infile:
    reader = csv.DictReader(infile)
    for row in reader:
        title_ids.append(row.get('id'))

# %%
len(title_ids)
# Out:
# 1134

# %%
def get_movies_data(title_ids):
    movies = []
    for batch in tqdm(list(batched(title_ids, 10))):
        response = requests.get(base_url + 'titles:batchGet?titleIds=' + '&titleIds='.join(batch))
        if response.ok:
            movies += [dict(
                id=movie.get('id'),
                title=movie.get('primaryTitle'),
                startYear=movie.get('startYear'),
                runtimeMinutes=round(movie.get('runtimeSeconds') / 60 if data.get('runtimeSeconds') else None),
                numVotes=movie.get('rating', {}).get('voteCount'),
                countryOfOrigin=','.join(country.get('code', '') for country in movie.get('originCountries', []))
                ) for movie in response.json().get('titles', [])]
    return movies

# %%
movies = get_movies_data(title_ids)
# Out:
# 100%|██████████| 114/114 [00:23<00:00,  4.77it/s]

# %%
len(movies)
# Out:
# 1134

# %%
def get_awards_info(movies):
    for movie in tqdm(movies):
        response = requests.get(base_url + endpoint + movie['id'] + '/awardNominations')
        if response.ok:
            movie['awardsOrNominations'] = True if response.json() else False
    return movies

# %%
movies = get_awards_info(movies)
movies
# Out:
# 100%|██████████| 1134/1134 [18:39<00:00,  1.01it/s]
# [{'id': 'tt0359950',
#   'title': 'The Secret Life of Walter Mitty',
#   'startYear': 2013,
#   'runtimeMinutes': 114,
#   'numVotes': 358680,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt0369610',
#   'title': 'Jurassic World',
#   'startYear': 2015,
#   'runtimeMinutes': 124,
#   'numVotes': 710065,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt0062622',
#   'title': '2001: A Space Odyssey',
#   'startYear': 1968,
#   'runtimeMinutes': 149,
#   'numVotes': 758947,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt0435651',
#   'title': 'The Giver',
#   'startYear': 2014,
#   'runtimeMinutes': 97,
#   'numVotes': 128925,
#   'countryOfOrigin': 'CA,ZA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt0437086',
#   'title': 'Alita: Battle Angel',
#   'startYear': 2019,
#   'runtimeMinutes': 122,
#   'numVotes': 314534,
#   'countryOfOrigin': 'JP,CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt0088178',
#   'title': 'Stop Making Sense',
#   'startYear': 1984,
#   'runtimeMinutes': 88,
#   'numVotes': 22937,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0145487',
#   'title': 'Spider-Man',
#   'startYear': 2002,
#   'runtimeMinutes': 121,
#   'numVotes': 931009,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0064816',
#   'title': 'The Swimming Pool',
#   'startYear': 1969,
#   'runtimeMinutes': 122,
#   'numVotes': 15308,
#   'countryOfOrigin': 'FR,IT',
#   'awardsOrNominations': False},
#  {'id': 'tt0439572',
#   'title': 'The Flash',
#   'startYear': 2023,
#   'runtimeMinutes': 144,
#   'numVotes': 237058,
#   'countryOfOrigin': 'US,CA,AU,NZ',
#   'awardsOrNominations': True},
#  {'id': 'tt0448115',
#   'title': 'Shazam!',
#   'startYear': 2019,
#   'runtimeMinutes': 132,
#   'numVotes': 403200,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt0490215',
#   'title': 'Silence',
#   'startYear': 2016,
#   'runtimeMinutes': 161,
#   'numVotes': 128581,
#   'countryOfOrigin': 'US,GB,IT,TW,MX,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt0455944',
#   'title': 'The Equalizer',
#   'startYear': 2014,
#   'runtimeMinutes': 132,
#   'numVotes': 449824,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0478970',
#   'title': 'Ant-Man',
#   'startYear': 2015,
#   'runtimeMinutes': 117,
#   'numVotes': 757288,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0493405',
#   'title': 'CHIPS',
#   'startYear': 2017,
#   'runtimeMinutes': 100,
#   'numVotes': 53099,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0451279',
#   'title': 'Wonder Woman',
#   'startYear': 2017,
#   'runtimeMinutes': 141,
#   'numVotes': 723323,
#   'countryOfOrigin': 'US,CN,HK',
#   'awardsOrNominations': True},
#  {'id': 'tt0790636',
#   'title': 'Dallas Buyers Club',
#   'startYear': 2013,
#   'runtimeMinutes': 117,
#   'numVotes': 537306,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0783640',
#   'title': 'The Last Full Measure',
#   'startYear': 2019,
#   'runtimeMinutes': 116,
#   'numVotes': 14983,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0816442',
#   'title': 'The Book Thief',
#   'startYear': 2013,
#   'runtimeMinutes': 131,
#   'numVotes': 145664,
#   'countryOfOrigin': 'DE,US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt0787474',
#   'title': 'The Boxtrolls',
#   'startYear': 2014,
#   'runtimeMinutes': 96,
#   'numVotes': 63566,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt0810819',
#   'title': 'The Danish Girl',
#   'startYear': 2015,
#   'runtimeMinutes': 119,
#   'numVotes': 204065,
#   'countryOfOrigin': 'GB,US,DE,DK,BE,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt0831387',
#   'title': 'Godzilla',
#   'startYear': 2014,
#   'runtimeMinutes': 123,
#   'numVotes': 456126,
#   'countryOfOrigin': 'US,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt0816692',
#   'title': 'Interstellar',
#   'startYear': 2014,
#   'runtimeMinutes': 169,
#   'numVotes': 2374947,
#   'countryOfOrigin': 'US,GB,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt0837563',
#   'title': 'Pet Sematary',
#   'startYear': 2019,
#   'runtimeMinutes': 100,
#   'numVotes': 102306,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt0864835',
#   'title': 'Mr. Peabody & Sherman',
#   'startYear': 2014,
#   'runtimeMinutes': 92,
#   'numVotes': 81707,
#   'countryOfOrigin': 'US,IN',
#   'awardsOrNominations': True},
#  {'id': 'tt0884732',
#   'title': 'The Wedding Ringer',
#   'startYear': 2015,
#   'runtimeMinutes': 101,
#   'numVotes': 83282,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0903657',
#   'title': 'Love & Mercy',
#   'startYear': 2014,
#   'runtimeMinutes': 121,
#   'numVotes': 44635,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0884726',
#   'title': "Legends of Oz: Dorothy's Return",
#   'startYear': 2013,
#   'runtimeMinutes': 88,
#   'numVotes': 6460,
#   'countryOfOrigin': 'US,IN,RU,NL',
#   'awardsOrNominations': True},
#  {'id': 'tt0870154',
#   'title': 'Jungle Cruise',
#   'startYear': 2021,
#   'runtimeMinutes': 127,
#   'numVotes': 222724,
#   'countryOfOrigin': 'US,HU,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt0859635',
#   'title': 'Super Troopers 2',
#   'startYear': 2018,
#   'runtimeMinutes': 99,
#   'numVotes': 29326,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt0918940',
#   'title': 'The Legend of Tarzan',
#   'startYear': 2016,
#   'runtimeMinutes': 110,
#   'numVotes': 194233,
#   'countryOfOrigin': 'GB,CA,US,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt10039344',
#   'title': 'Countdown',
#   'startYear': 2019,
#   'runtimeMinutes': 90,
#   'numVotes': 50413,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt0974015',
#   'title': 'Justice League',
#   'startYear': 2017,
#   'runtimeMinutes': 120,
#   'numVotes': 494623,
#   'countryOfOrigin': 'US,CA,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt0993846',
#   'title': 'The Wolf of Wall Street',
#   'startYear': 2013,
#   'runtimeMinutes': 180,
#   'numVotes': 1703709,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10011448',
#   'title': 'Linda Ronstadt: The Sound of My Voice',
#   'startYear': 2019,
#   'runtimeMinutes': 95,
#   'numVotes': 2598,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10016180',
#   'title': 'The Little Things',
#   'startYear': 2021,
#   'runtimeMinutes': 128,
#   'numVotes': 135278,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10059518',
#   'title': 'Unhinged',
#   'startYear': 2020,
#   'runtimeMinutes': 90,
#   'numVotes': 84205,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1020072',
#   'title': 'Selma',
#   'startYear': 2014,
#   'runtimeMinutes': 128,
#   'numVotes': 97885,
#   'countryOfOrigin': 'US,GB,FR',
#   'awardsOrNominations': True},
#  {'id': 'tt10195452',
#   'title': 'American Skin',
#   'startYear': 2019,
#   'runtimeMinutes': 90,
#   'numVotes': 4098,
#   'countryOfOrigin': 'IT,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10098448',
#   'title': 'Jesus Revolution',
#   'startYear': 2023,
#   'runtimeMinutes': 120,
#   'numVotes': 15860,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10160976',
#   'title': 'The Nun II',
#   'startYear': 2023,
#   'runtimeMinutes': 110,
#   'numVotes': 71999,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10314450',
#   'title': 'Becky',
#   'startYear': 2020,
#   'runtimeMinutes': 93,
#   'numVotes': 28070,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1025100',
#   'title': 'Gemini Man',
#   'startYear': 2019,
#   'runtimeMinutes': 117,
#   'numVotes': 128318,
#   'countryOfOrigin': 'US,CN,CO',
#   'awardsOrNominations': True},
#  {'id': 'tt1029360',
#   'title': 'Poltergeist',
#   'startYear': 2015,
#   'runtimeMinutes': 93,
#   'numVotes': 63408,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10298810',
#   'title': 'Lightyear',
#   'startYear': 2022,
#   'runtimeMinutes': 105,
#   'numVotes': 131796,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10298840',
#   'title': 'Strange World',
#   'startYear': 2022,
#   'runtimeMinutes': 102,
#   'numVotes': 49081,
#   'countryOfOrigin': 'US,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt10362466',
#   'title': 'After We Collided',
#   'startYear': 2020,
#   'runtimeMinutes': 105,
#   'numVotes': 42217,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10342730',
#   'title': 'Spiral',
#   'startYear': 2021,
#   'runtimeMinutes': 93,
#   'numVotes': 73943,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10341196',
#   'title': 'Gigi & Nate',
#   'startYear': 2022,
#   'runtimeMinutes': 114,
#   'numVotes': 2391,
#   'countryOfOrigin': 'CH,GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10327252',
#   'title': 'The Forever Purge',
#   'startYear': 2021,
#   'runtimeMinutes': 103,
#   'numVotes': 46862,
#   'countryOfOrigin': 'CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10366206',
#   'title': 'John Wick: Chapter 4',
#   'startYear': 2023,
#   'runtimeMinutes': 169,
#   'numVotes': 387514,
#   'countryOfOrigin': 'US,DE',
#   'awardsOrNominations': True},
#  {'id': 'tt10473036',
#   'title': 'The Amazing Maurice',
#   'startYear': 2022,
#   'runtimeMinutes': 93,
#   'numVotes': 6311,
#   'countryOfOrigin': 'GB,DE,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1043726',
#   'title': 'The Legend of Hercules',
#   'startYear': 2014,
#   'runtimeMinutes': 99,
#   'numVotes': 57219,
#   'countryOfOrigin': 'US,BG,DE',
#   'awardsOrNominations': True},
#  {'id': 'tt10403420',
#   'title': 'Terrifier 2',
#   'startYear': 2022,
#   'runtimeMinutes': 138,
#   'numVotes': 75206,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10370710',
#   'title': 'The Worst Person in the World',
#   'startYear': 2021,
#   'runtimeMinutes': 128,
#   'numVotes': 113566,
#   'countryOfOrigin': 'NO,FR,SE,DK',
#   'awardsOrNominations': True},
#  {'id': 'tt10638522',
#   'title': 'Talk to Me',
#   'startYear': 2022,
#   'runtimeMinutes': 95,
#   'numVotes': 191091,
#   'countryOfOrigin': 'AU,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt10515926',
#   'title': 'Half Brothers',
#   'startYear': 2020,
#   'runtimeMinutes': 96,
#   'numVotes': 4477,
#   'countryOfOrigin': 'MX,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10545296',
#   'title': 'The Hunger Games: The Ballad of Songbirds & Snakes',
#   'startYear': 2023,
#   'runtimeMinutes': 157,
#   'numVotes': 165538,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10648342',
#   'title': 'Thor: Love and Thunder',
#   'startYear': 2022,
#   'runtimeMinutes': 118,
#   'numVotes': 439597,
#   'countryOfOrigin': 'AU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10633456',
#   'title': 'Minari',
#   'startYear': 2020,
#   'runtimeMinutes': 115,
#   'numVotes': 105020,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1051904',
#   'title': 'Goosebumps',
#   'startYear': 2015,
#   'runtimeMinutes': 103,
#   'numVotes': 99451,
#   'countryOfOrigin': 'US,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt10676048',
#   'title': 'The Marvels',
#   'startYear': 2023,
#   'runtimeMinutes': 105,
#   'numVotes': 153166,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10720352',
#   'title': 'Arthur the King',
#   'startYear': 2024,
#   'runtimeMinutes': 107,
#   'numVotes': 35517,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10655524',
#   'title': 'It Ends with Us',
#   'startYear': 2024,
#   'runtimeMinutes': 130,
#   'numVotes': 90012,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10661180',
#   'title': 'The Last Shift',
#   'startYear': 2020,
#   'runtimeMinutes': 90,
#   'numVotes': 4380,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10665338',
#   'title': 'Halloween Kills',
#   'startYear': 2021,
#   'runtimeMinutes': 105,
#   'numVotes': 104558,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1083452',
#   'title': 'Eddie the Eagle',
#   'startYear': 2015,
#   'runtimeMinutes': 106,
#   'numVotes': 104669,
#   'countryOfOrigin': 'GB,DE,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10731256',
#   'title': "Don't Worry Darling",
#   'startYear': 2022,
#   'runtimeMinutes': 123,
#   'numVotes': 167862,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1072748',
#   'title': 'Winchester',
#   'startYear': 2018,
#   'runtimeMinutes': 99,
#   'numVotes': 38345,
#   'countryOfOrigin': 'AU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1082807',
#   'title': 'The Belko Experiment',
#   'startYear': 2016,
#   'runtimeMinutes': 89,
#   'numVotes': 64080,
#   'countryOfOrigin': 'US,CO',
#   'awardsOrNominations': False},
#  {'id': 'tt10838180',
#   'title': 'The Matrix Resurrections',
#   'startYear': 2021,
#   'runtimeMinutes': 148,
#   'numVotes': 295238,
#   'countryOfOrigin': 'US,AU'},
#  {'id': 'tt1091191',
#   'title': 'Lone Survivor',
#   'startYear': 2013,
#   'runtimeMinutes': 121,
#   'numVotes': 317184,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10919380',
#   'title': 'Freaky',
#   'startYear': 2020,
#   'runtimeMinutes': 102,
#   'numVotes': 78570,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10855768',
#   'title': 'Missing',
#   'startYear': 2023,
#   'runtimeMinutes': 111,
#   'numVotes': 68822,
#   'countryOfOrigin': 'US,RU',
#   'awardsOrNominations': True},
#  {'id': 'tt10944596',
#   'title': 'Here Today',
#   'startYear': 2021,
#   'runtimeMinutes': 117,
#   'numVotes': 6374,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt10954600',
#   'title': 'Ant-Man and the Wasp: Quantumania',
#   'startYear': 2023,
#   'runtimeMinutes': 124,
#   'numVotes': 255171,
#   'countryOfOrigin': 'US,AU,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt10872600',
#   'title': 'Spider-Man: No Way Home',
#   'startYear': 2021,
#   'runtimeMinutes': 148,
#   'numVotes': 964861,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1086064',
#   'title': 'Bill & Ted Face the Music',
#   'startYear': 2020,
#   'runtimeMinutes': 91,
#   'numVotes': 55321,
#   'countryOfOrigin': 'BS,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1086772',
#   'title': 'Blended',
#   'startYear': 2014,
#   'runtimeMinutes': 117,
#   'numVotes': 153113,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt10954984',
#   'title': 'Nope',
#   'startYear': 2022,
#   'runtimeMinutes': 130,
#   'numVotes': 302569,
#   'countryOfOrigin': 'CA,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt10954652',
#   'title': 'Old',
#   'startYear': 2021,
#   'runtimeMinutes': 108,
#   'numVotes': 177819,
#   'countryOfOrigin': 'CN,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt11020728',
#   'title': 'Long Weekend',
#   'startYear': 2021,
#   'runtimeMinutes': 91,
#   'numVotes': 2198,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt11083552',
#   'title': 'Wrath of Man',
#   'startYear': 2021,
#   'runtimeMinutes': 119,
#   'numVotes': 227578,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt11003218',
#   'title': 'Pig',
#   'startYear': 2021,
#   'runtimeMinutes': 92,
#   'numVotes': 100458,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1109624',
#   'title': 'Paddington',
#   'startYear': 2014,
#   'runtimeMinutes': 95,
#   'numVotes': 149091,
#   'countryOfOrigin': 'GB,FR',
#   'awardsOrNominations': True},
#  {'id': 'tt11084896',
#   'title': 'Spirit Untamed',
#   'startYear': 2021,
#   'runtimeMinutes': 88,
#   'numVotes': 5217,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt11057302',
#   'title': 'Madame Web',
#   'startYear': 2024,
#   'runtimeMinutes': 116,
#   'numVotes': 104586,
#   'countryOfOrigin': 'US,MX,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt11032374',
#   'title': 'Demon Slayer: Kimetsu no Yaiba - The Movie: Mugen Train',
#   'startYear': 2020,
#   'runtimeMinutes': 117,
#   'numVotes': 86406,
#   'countryOfOrigin': 'JP',
#   'awardsOrNominations': True},
#  {'id': 'tt11128440',
#   'title': 'Clerks III',
#   'startYear': 2022,
#   'runtimeMinutes': 100,
#   'numVotes': 20873,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt11125620',
#   'title': 'The Addams Family 2',
#   'startYear': 2021,
#   'runtimeMinutes': 93,
#   'numVotes': 16924,
#   'countryOfOrigin': 'US,CA,VN,FR,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt11138512',
#   'title': 'The Northman',
#   'startYear': 2022,
#   'runtimeMinutes': 137,
#   'numVotes': 282932,
#   'countryOfOrigin': 'GB,CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt11229780',
#   'title': 'Infidel',
#   'startYear': 2019,
#   'runtimeMinutes': 108,
#   'numVotes': 4096,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11245972',
#   'title': 'Scream',
#   'startYear': 2022,
#   'runtimeMinutes': 114,
#   'numVotes': 176360,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11152168',
#   'title': 'IF',
#   'startYear': 2024,
#   'runtimeMinutes': 104,
#   'numVotes': 60388,
#   'countryOfOrigin': 'CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt11169050',
#   'title': 'Supernova',
#   'startYear': 2020,
#   'runtimeMinutes': 95,
#   'numVotes': 15638,
#   'countryOfOrigin': 'GB',
#   'awardsOrNominations': True},
#  {'id': 'tt11214590',
#   'title': 'House of Gucci',
#   'startYear': 2021,
#   'runtimeMinutes': 158,
#   'numVotes': 169666,
#   'countryOfOrigin': 'US,CA,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt11271038',
#   'title': 'Licorice Pizza',
#   'startYear': 2021,
#   'runtimeMinutes': 133,
#   'numVotes': 149483,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1126590',
#   'title': 'Big Eyes',
#   'startYear': 2014,
#   'runtimeMinutes': 106,
#   'numVotes': 102794,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt11252248',
#   'title': 'Dog',
#   'startYear': 2022,
#   'runtimeMinutes': 101,
#   'numVotes': 49957,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11145118',
#   'title': 'Creed III',
#   'startYear': 2023,
#   'runtimeMinutes': 116,
#   'numVotes': 101775,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11285280',
#   'title': 'Together Together',
#   'startYear': 2021,
#   'runtimeMinutes': 90,
#   'numVotes': 9792,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11304740',
#   'title': 'Wish',
#   'startYear': 2023,
#   'runtimeMinutes': 95,
#   'numVotes': 47671,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11349958',
#   'title': 'Merci pour tout',
#   'startYear': 2019,
#   'runtimeMinutes': 99,
#   'numVotes': 317,
#   'countryOfOrigin': 'CA',
#   'awardsOrNominations': True},
#  {'id': 'tt7378922',
#   'title': 'Summer of Soul (...Or, When the Revolution Could Not Be Televised)',
#   'startYear': 2021,
#   'runtimeMinutes': 118,
#   'numVotes': 14823,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11466222',
#   'title': 'Jackass Forever',
#   'startYear': 2022,
#   'runtimeMinutes': 96,
#   'numVotes': 53729,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11614912',
#   'title': 'She Dies Tomorrow',
#   'startYear': 2020,
#   'runtimeMinutes': 86,
#   'numVotes': 7664,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1170358',
#   'title': 'The Hobbit: The Desolation of Smaug',
#   'startYear': 2013,
#   'runtimeMinutes': 161,
#   'numVotes': 735558,
#   'countryOfOrigin': 'NZ,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1137450',
#   'title': 'Death Wish',
#   'startYear': 2018,
#   'runtimeMinutes': 107,
#   'numVotes': 79832,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt11389872',
#   'title': 'Kingdom of the Planet of the Apes',
#   'startYear': 2024,
#   'runtimeMinutes': 145,
#   'numVotes': 156295,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11535358',
#   'title': 'Family Camp',
#   'startYear': 2022,
#   'runtimeMinutes': 111,
#   'numVotes': 3028,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1160419',
#   'title': 'Dune: Part One',
#   'startYear': 2021,
#   'runtimeMinutes': 155,
#   'numVotes': 967722,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt11762114',
#   'title': 'Mean Girls',
#   'startYear': 2024,
#   'runtimeMinutes': 112,
#   'numVotes': 38058,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11832046',
#   'title': 'PAW Patrol: The Movie',
#   'startYear': 2021,
#   'runtimeMinutes': 86,
#   'numVotes': 9152,
#   'countryOfOrigin': 'CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt11729298',
#   'title': 'American Underdog',
#   'startYear': 2021,
#   'runtimeMinutes': 112,
#   'numVotes': 26668,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt11813216',
#   'title': 'The Banshees of Inisherin',
#   'startYear': 2022,
#   'runtimeMinutes': 114,
#   'numVotes': 282226,
#   'countryOfOrigin': 'IE,GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1200263',
#   'title': 'The Color Purple',
#   'startYear': 2023,
#   'runtimeMinutes': 141,
#   'numVotes': 19426,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11858890',
#   'title': 'The Creator',
#   'startYear': 2023,
#   'runtimeMinutes': 133,
#   'numVotes': 188216,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt11790780',
#   'title': 'The Alpinist',
#   'startYear': 2021,
#   'runtimeMinutes': 92,
#   'numVotes': 16054,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1179933',
#   'title': '10 Cloverfield Lane',
#   'startYear': 2016,
#   'runtimeMinutes': 103,
#   'numVotes': 373983,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1204977',
#   'title': 'Ouija',
#   'startYear': 2014,
#   'runtimeMinutes': 89,
#   'numVotes': 60404,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt12003946',
#   'title': 'Violent Night',
#   'startYear': 2022,
#   'runtimeMinutes': 112,
#   'numVotes': 114761,
#   'countryOfOrigin': 'CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1213641',
#   'title': 'First Man',
#   'startYear': 2018,
#   'runtimeMinutes': 141,
#   'numVotes': 211386,
#   'countryOfOrigin': 'CN,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt12193804',
#   'title': 'Whitney Houston: I Wanna Dance with Somebody',
#   'startYear': 2022,
#   'runtimeMinutes': 144,
#   'numVotes': 25938,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1219827',
#   'title': 'Ghost in the Shell',
#   'startYear': 2017,
#   'runtimeMinutes': 107,
#   'numVotes': 235499,
#   'countryOfOrigin': 'US,IN,HK,CN,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1206885',
#   'title': 'Rambo: Last Blood',
#   'startYear': 2019,
#   'runtimeMinutes': 89,
#   'numVotes': 116139,
#   'countryOfOrigin': 'US,HK,FR,BG,ES,SE,PT',
#   'awardsOrNominations': True},
#  {'id': 'tt1226837',
#   'title': 'Beautiful Boy',
#   'startYear': 2018,
#   'runtimeMinutes': 120,
#   'numVotes': 117240,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1211837',
#   'title': 'Doctor Strange',
#   'startYear': 2016,
#   'runtimeMinutes': 115,
#   'numVotes': 850490,
#   'countryOfOrigin': 'US,HK,NP',
#   'awardsOrNominations': True},
#  {'id': 'tt1205537',
#   'title': 'Jack Ryan: Shadow Recruit',
#   'startYear': 2014,
#   'runtimeMinutes': 105,
#   'numVotes': 141066,
#   'countryOfOrigin': 'US,RU,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt12261776',
#   'title': '65',
#   'startYear': 2023,
#   'runtimeMinutes': 93,
#   'numVotes': 101731,
#   'countryOfOrigin': 'US,IE,AU,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1212428',
#   'title': 'The Lost City of Z',
#   'startYear': 2016,
#   'runtimeMinutes': 141,
#   'numVotes': 103360,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1229340',
#   'title': 'Anchorman 2: The Legend Continues',
#   'startYear': 2013,
#   'runtimeMinutes': 119,
#   'numVotes': 198321,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1255919',
#   'title': 'Holmes & Watson',
#   'startYear': 2018,
#   'runtimeMinutes': 90,
#   'numVotes': 40952,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt12584954',
#   'title': 'Twisters',
#   'startYear': 2024,
#   'runtimeMinutes': 122,
#   'numVotes': 178978,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt12593682',
#   'title': 'Bullet Train',
#   'startYear': 2022,
#   'runtimeMinutes': 127,
#   'numVotes': 500726,
#   'countryOfOrigin': 'US,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt1234721',
#   'title': 'RoboCop',
#   'startYear': 2014,
#   'runtimeMinutes': 117,
#   'numVotes': 245701,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1230168',
#   'title': 'Same Kind of Different as Me',
#   'startYear': 2017,
#   'runtimeMinutes': 119,
#   'numVotes': 8973,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1270797',
#   'title': 'Venom',
#   'startYear': 2018,
#   'runtimeMinutes': 112,
#   'numVotes': 583707,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt1259528',
#   'title': 'Den of Thieves',
#   'startYear': 2018,
#   'runtimeMinutes': 140,
#   'numVotes': 146934,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1267297',
#   'title': 'Hercules',
#   'startYear': 2014,
#   'runtimeMinutes': 98,
#   'numVotes': 168865,
#   'countryOfOrigin': 'HU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1253863',
#   'title': '300: Rise of an Empire',
#   'startYear': 2014,
#   'runtimeMinutes': 102,
#   'numVotes': 324636,
#   'countryOfOrigin': 'US,BG',
#   'awardsOrNominations': True},
#  {'id': 'tt12412888',
#   'title': 'Sonic the Hedgehog 2',
#   'startYear': 2022,
#   'runtimeMinutes': 122,
#   'numVotes': 109268,
#   'countryOfOrigin': 'US,JP,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt12758486',
#   'title': 'Chevalier',
#   'startYear': 2022,
#   'runtimeMinutes': 108,
#   'numVotes': 7722,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt12873300',
#   'title': 'Sight',
#   'startYear': 2023,
#   'runtimeMinutes': 103,
#   'numVotes': 1791,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt12789558',
#   'title': 'Belfast',
#   'startYear': 2021,
#   'runtimeMinutes': 98,
#   'numVotes': 98512,
#   'countryOfOrigin': 'GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1291150',
#   'title': 'Teenage Mutant Ninja Turtles',
#   'startYear': 2014,
#   'runtimeMinutes': 101,
#   'numVotes': 226132,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt12873562',
#   'title': 'The Invitation',
#   'startYear': 2022,
#   'runtimeMinutes': 105,
#   'numVotes': 38969,
#   'countryOfOrigin': 'US,HU',
#   'awardsOrNominations': True},
#  {'id': 'tt12844910',
#   'title': 'Pathaan',
#   'startYear': 2023,
#   'runtimeMinutes': 146,
#   'numVotes': 161764,
#   'countryOfOrigin': 'IN',
#   'awardsOrNominations': True},
#  {'id': 'tt1285009',
#   'title': 'The Strangers: Prey at Night',
#   'startYear': 2018,
#   'runtimeMinutes': 85,
#   'numVotes': 38355,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': False},
#  {'id': 'tt1293847',
#   'title': 'xXx: Return of Xander Cage',
#   'startYear': 2017,
#   'runtimeMinutes': 107,
#   'numVotes': 100098,
#   'countryOfOrigin': 'CN,CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1292566',
#   'title': 'How to Be Single',
#   'startYear': 2016,
#   'runtimeMinutes': 110,
#   'numVotes': 97484,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt12921446',
#   'title': 'The Exorcist: Believer',
#   'startYear': 2023,
#   'runtimeMinutes': 111,
#   'numVotes': 47666,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13087796',
#   'title': "I'm Your Man",
#   'startYear': 2021,
#   'runtimeMinutes': 108,
#   'numVotes': 14422,
#   'countryOfOrigin': 'DE',
#   'awardsOrNominations': True},
#  {'id': 'tt1298644',
#   'title': 'The Hustle',
#   'startYear': 2019,
#   'runtimeMinutes': 93,
#   'numVotes': 69288,
#   'countryOfOrigin': 'US,ES',
#   'awardsOrNominations': True},
#  {'id': 'tt12971924',
#   'title': 'The Call',
#   'startYear': 2020,
#   'runtimeMinutes': 97,
#   'numVotes': 5529,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': False},
#  {'id': 'tt13204490',
#   'title': 'Petite Maman',
#   'startYear': 2021,
#   'runtimeMinutes': 73,
#   'numVotes': 19766,
#   'countryOfOrigin': 'FR',
#   'awardsOrNominations': True},
#  {'id': 'tt13238346',
#   'title': 'Past Lives',
#   'startYear': 2023,
#   'runtimeMinutes': 105,
#   'numVotes': 156630,
#   'countryOfOrigin': 'US,KR',
#   'awardsOrNominations': True},
#  {'id': 'tt13223398',
#   'title': 'Beast',
#   'startYear': 2022,
#   'runtimeMinutes': 93,
#   'numVotes': 46687,
#   'countryOfOrigin': 'IS,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1322269',
#   'title': 'August: Osage County',
#   'startYear': 2013,
#   'runtimeMinutes': 121,
#   'numVotes': 97966,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13097932',
#   'title': 'One Life',
#   'startYear': 2023,
#   'runtimeMinutes': 109,
#   'numVotes': 35645,
#   'countryOfOrigin': 'GB,CZ,AU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt13320622',
#   'title': 'The Lost City',
#   'startYear': 2022,
#   'runtimeMinutes': 112,
#   'numVotes': 171410,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13287846',
#   'title': 'Napoleon',
#   'startYear': 2023,
#   'runtimeMinutes': 158,
#   'numVotes': 175752,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1340138',
#   'title': 'Terminator Genisys',
#   'startYear': 2015,
#   'runtimeMinutes': 126,
#   'numVotes': 301656,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt13345606',
#   'title': 'Evil Dead Rise',
#   'startYear': 2023,
#   'runtimeMinutes': 96,
#   'numVotes': 157998,
#   'countryOfOrigin': 'IE,NZ,US',
#   'awardsOrNominations': True},
#  {'id': 'tt13321244',
#   'title': 'Origin',
#   'startYear': 2023,
#   'runtimeMinutes': 141,
#   'numVotes': 7601,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13327144',
#   'title': 'The Forgotten Carols',
#   'startYear': 2020,
#   'runtimeMinutes': 130,
#   'numVotes': 85,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt13375076',
#   'title': "The Pope's Exorcist",
#   'startYear': 2023,
#   'runtimeMinutes': 103,
#   'numVotes': 97705,
#   'countryOfOrigin': 'US,ES,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt13405778',
#   'title': 'Insidious: The Red Door',
#   'startYear': 2023,
#   'runtimeMinutes': 107,
#   'numVotes': 59502,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt13429870',
#   'title': 'Robot Dreams',
#   'startYear': 2023,
#   'runtimeMinutes': 103,
#   'numVotes': 22162,
#   'countryOfOrigin': 'ES,FR',
#   'awardsOrNominations': True},
#  {'id': 'tt13502506',
#   'title': "L'Arracheuse de temps",
#   'startYear': 2021,
#   'runtimeMinutes': 105,
#   'numVotes': 325,
#   'countryOfOrigin': 'CA',
#   'awardsOrNominations': True},
#  {'id': 'tt13433802',
#   'title': 'A Quiet Place: Day One',
#   'startYear': 2024,
#   'runtimeMinutes': 99,
#   'numVotes': 157072,
#   'countryOfOrigin': 'US,GB,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt13521006',
#   'title': 'Beau Is Afraid',
#   'startYear': 2023,
#   'runtimeMinutes': 179,
#   'numVotes': 73310,
#   'countryOfOrigin': 'US,GB,FI,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1361336',
#   'title': 'Tom & Jerry',
#   'startYear': 2021,
#   'runtimeMinutes': 101,
#   'numVotes': 41917,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1365519',
#   'title': 'Tomb Raider',
#   'startYear': 2018,
#   'runtimeMinutes': 119,
#   'numVotes': 235779,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1355631',
#   'title': 'The Infiltrator',
#   'startYear': 2016,
#   'runtimeMinutes': 127,
#   'numVotes': 83278,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1355630',
#   'title': 'If I Stay',
#   'startYear': 2014,
#   'runtimeMinutes': 107,
#   'numVotes': 130188,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13669038',
#   'title': 'Women Talking',
#   'startYear': 2022,
#   'runtimeMinutes': 104,
#   'numVotes': 46344,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13751694',
#   'title': 'Animal',
#   'startYear': 2023,
#   'runtimeMinutes': 204,
#   'numVotes': 107744,
#   'countryOfOrigin': 'IN',
#   'awardsOrNominations': True},
#  {'id': 'tt1371150',
#   'title': 'This Is Where I Leave You',
#   'startYear': 2014,
#   'runtimeMinutes': 103,
#   'numVotes': 92605,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1355683',
#   'title': 'Black Mass',
#   'startYear': 2015,
#   'runtimeMinutes': 123,
#   'numVotes': 199098,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1355644',
#   'title': 'Passengers',
#   'startYear': 2016,
#   'runtimeMinutes': 116,
#   'numVotes': 478682,
#   'countryOfOrigin': 'HK,AU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt13820428',
#   'title': 'Witnesses',
#   'startYear': 2021,
#   'runtimeMinutes': 110,
#   'numVotes': 465,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt1390411',
#   'title': 'In the Heart of the Sea',
#   'startYear': 2015,
#   'runtimeMinutes': 122,
#   'numVotes': 155854,
#   'countryOfOrigin': 'US,AU,ES',
#   'awardsOrNominations': True},
#  {'id': 'tt13833688',
#   'title': 'The Whale',
#   'startYear': 2022,
#   'runtimeMinutes': 117,
#   'numVotes': 249852,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt13848804',
#   'title': 'Journey to Bethlehem',
#   'startYear': 2023,
#   'runtimeMinutes': 99,
#   'numVotes': 3431,
#   'countryOfOrigin': 'US,ES',
#   'awardsOrNominations': True},
#  {'id': 'tt1386697',
#   'title': 'Suicide Squad',
#   'startYear': 2016,
#   'runtimeMinutes': 123,
#   'numVotes': 744681,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1396484',
#   'title': 'It',
#   'startYear': 2017,
#   'runtimeMinutes': 135,
#   'numVotes': 650126,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt13957560',
#   'title': 'Dumb Money',
#   'startYear': 2023,
#   'runtimeMinutes': 105,
#   'numVotes': 58461,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1392190',
#   'title': 'Mad Max: Fury Road',
#   'startYear': 2015,
#   'runtimeMinutes': 120,
#   'numVotes': 1173873,
#   'countryOfOrigin': 'AU,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1389139',
#   'title': 'When the Bough Breaks',
#   'startYear': 2016,
#   'runtimeMinutes': 107,
#   'numVotes': 8588,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14051976',
#   'title': 'Camp Hideout',
#   'startYear': 2023,
#   'runtimeMinutes': 100,
#   'numVotes': 1155,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt1398426',
#   'title': 'Straight Outta Compton',
#   'startYear': 2015,
#   'runtimeMinutes': 147,
#   'numVotes': 228622,
#   'countryOfOrigin': 'US,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt14109724',
#   'title': 'Ticket to Paradise',
#   'startYear': 2022,
#   'runtimeMinutes': 104,
#   'numVotes': 78774,
#   'countryOfOrigin': 'GB,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1413492',
#   'title': '12 Strong',
#   'startYear': 2018,
#   'runtimeMinutes': 130,
#   'numVotes': 97678,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14061478',
#   'title': 'Lamb of God: The Concert Film',
#   'startYear': 2021,
#   'runtimeMinutes': 90,
#   'numVotes': 165,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt1418377',
#   'title': 'I, Frankenstein',
#   'startYear': 2014,
#   'runtimeMinutes': 92,
#   'numVotes': 85186,
#   'countryOfOrigin': 'US,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt14088510',
#   'title': 'Tarot',
#   'startYear': 2024,
#   'runtimeMinutes': 92,
#   'numVotes': 33306,
#   'countryOfOrigin': 'RS,US',
#   'awardsOrNominations': True},
#  {'id': 'tt14097180',
#   'title': 'Somewhere in Queens',
#   'startYear': 2022,
#   'runtimeMinutes': 106,
#   'numVotes': 6110,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14208870',
#   'title': 'The Fabelmans',
#   'startYear': 2022,
#   'runtimeMinutes': 151,
#   'numVotes': 129425,
#   'countryOfOrigin': 'US,IN',
#   'awardsOrNominations': True},
#  {'id': 'tt14209916',
#   'title': 'Cocaine Bear',
#   'startYear': 2023,
#   'runtimeMinutes': 95,
#   'numVotes': 121922,
#   'countryOfOrigin': 'US,IE,NZ,NL,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt14230388',
#   'title': 'Asteroid City',
#   'startYear': 2023,
#   'runtimeMinutes': 105,
#   'numVotes': 135798,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1408253',
#   'title': 'Ride Along',
#   'startYear': 2014,
#   'runtimeMinutes': 99,
#   'numVotes': 127149,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1433813',
#   'title': 'Hubble',
#   'startYear': 2010,
#   'runtimeMinutes': 45,
#   'numVotes': 4615,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt14351082',
#   'title': 'Cabrini',
#   'startYear': 2024,
#   'runtimeMinutes': 142,
#   'numVotes': 9181,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14362112',
#   'title': 'Trolls Band Together',
#   'startYear': 2023,
#   'runtimeMinutes': 91,
#   'numVotes': 18622,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1431045',
#   'title': 'Deadpool',
#   'startYear': 2016,
#   'runtimeMinutes': 108,
#   'numVotes': 1216174,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14439896',
#   'title': 'Father Stu',
#   'startYear': 2022,
#   'runtimeMinutes': 124,
#   'numVotes': 34448,
#   'countryOfOrigin': 'US,KR',
#   'awardsOrNominations': True},
#  {'id': 'tt14230458',
#   'title': 'Poor Things',
#   'startYear': 2023,
#   'runtimeMinutes': 141,
#   'numVotes': 348126,
#   'countryOfOrigin': 'IE,GB,US,HU',
#   'awardsOrNominations': True},
#  {'id': 'tt14454876',
#   'title': 'Golda',
#   'startYear': 2023,
#   'runtimeMinutes': 100,
#   'numVotes': 14441,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt14444726',
#   'title': 'Tár',
#   'startYear': 2022,
#   'runtimeMinutes': 158,
#   'numVotes': 105032,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14331144',
#   'title': 'Jujutsu Kaisen 0',
#   'startYear': 2021,
#   'runtimeMinutes': 112,
#   'numVotes': 51575,
#   'countryOfOrigin': 'JP',
#   'awardsOrNominations': True},
#  {'id': 'tt1430612',
#   'title': 'Brick Mansions',
#   'startYear': 2014,
#   'runtimeMinutes': 90,
#   'numVotes': 45141,
#   'countryOfOrigin': 'FR,CA,US,ES',
#   'awardsOrNominations': True},
#  {'id': 'tt14539740',
#   'title': 'Godzilla x Kong: The New Empire',
#   'startYear': 2024,
#   'runtimeMinutes': 115,
#   'numVotes': 125529,
#   'countryOfOrigin': 'US,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt14561712',
#   'title': 'La Chimera',
#   'startYear': 2023,
#   'runtimeMinutes': 131,
#   'numVotes': 18577,
#   'countryOfOrigin': 'IT,FR,CH,TR',
#   'awardsOrNominations': True},
#  {'id': 'tt1448754',
#   'title': 'Thanksgiving',
#   'startYear': 2023,
#   'runtimeMinutes': 106,
#   'numVotes': 72995,
#   'countryOfOrigin': 'US,CA,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt14537248',
#   'title': 'Nefarious',
#   'startYear': 2023,
#   'runtimeMinutes': 97,
#   'numVotes': 35502,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14614892',
#   'title': 'Dragon Ball Super: Super Hero',
#   'startYear': 2022,
#   'runtimeMinutes': 100,
#   'numVotes': 17567,
#   'countryOfOrigin': 'JP',
#   'awardsOrNominations': True},
#  {'id': 'tt1454468',
#   'title': 'Gravity',
#   'startYear': 2013,
#   'runtimeMinutes': 91,
#   'numVotes': 885003,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1458169',
#   'title': 'Kidnap',
#   'startYear': 2017,
#   'runtimeMinutes': 95,
#   'numVotes': 40414,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14570440',
#   'title': 'Radical',
#   'startYear': 2023,
#   'runtimeMinutes': 125,
#   'numVotes': 6981,
#   'countryOfOrigin': 'US,MX',
#   'awardsOrNominations': True},
#  {'id': 'tt1464335',
#   'title': 'Uncharted',
#   'startYear': 2022,
#   'runtimeMinutes': 116,
#   'numVotes': 286003,
#   'countryOfOrigin': 'ES,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1462764',
#   'title': 'Indiana Jones and the Dial of Destiny',
#   'startYear': 2023,
#   'runtimeMinutes': 154,
#   'numVotes': 222690,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14849194',
#   'title': 'The Holdovers',
#   'startYear': 2023,
#   'runtimeMinutes': 133,
#   'numVotes': 203222,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt14668630',
#   'title': 'Lyle, Lyle, Crocodile',
#   'startYear': 2022,
#   'runtimeMinutes': 106,
#   'numVotes': 17190,
#   'countryOfOrigin': 'US,GB,IT',
#   'awardsOrNominations': True},
#  {'id': 'tt1485796',
#   'title': 'The Greatest Showman',
#   'startYear': 2017,
#   'runtimeMinutes': 105,
#   'numVotes': 333617,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt1489887',
#   'title': 'Booksmart',
#   'startYear': 2019,
#   'runtimeMinutes': 102,
#   'numVotes': 137556,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1478839',
#   'title': 'The Art of Racing in the Rain',
#   'startYear': 2019,
#   'runtimeMinutes': 109,
#   'numVotes': 42791,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt1477834',
#   'title': 'Aquaman',
#   'startYear': 2018,
#   'runtimeMinutes': 143,
#   'numVotes': 540847,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1469304',
#   'title': 'Baywatch',
#   'startYear': 2017,
#   'runtimeMinutes': 116,
#   'numVotes': 212833,
#   'countryOfOrigin': 'GB,CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1490017',
#   'title': 'The Lego Movie',
#   'startYear': 2014,
#   'runtimeMinutes': 100,
#   'numVotes': 404666,
#   'countryOfOrigin': 'US,DK,AU,NO',
#   'awardsOrNominations': True},
#  {'id': 'tt1489889',
#   'title': 'Central Intelligence',
#   'startYear': 2016,
#   'runtimeMinutes': 107,
#   'numVotes': 228561,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt14966898',
#   'title': 'Late Night with the Devil',
#   'startYear': 2023,
#   'runtimeMinutes': 93,
#   'numVotes': 130688,
#   'countryOfOrigin': 'AU,AE,US',
#   'awardsOrNominations': True},
#  {'id': 'tt15078804',
#   'title': 'Problemista',
#   'startYear': 2023,
#   'runtimeMinutes': 104,
#   'numVotes': 8708,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15109082',
#   'title': 'The Quiet Girl',
#   'startYear': 2022,
#   'runtimeMinutes': 95,
#   'numVotes': 26462,
#   'countryOfOrigin': 'IE',
#   'awardsOrNominations': True},
#  {'id': 'tt1502397',
#   'title': 'Bad Boys for Life',
#   'startYear': 2020,
#   'runtimeMinutes': 124,
#   'numVotes': 191784,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15239678',
#   'title': 'Dune: Part Two',
#   'startYear': 2024,
#   'runtimeMinutes': 166,
#   'numVotes': 650191,
#   'countryOfOrigin': 'US,CA,AE,HU,IT,NZ,JO,GM',
#   'awardsOrNominations': True},
#  {'id': 'tt1502407',
#   'title': 'Halloween',
#   'startYear': 2018,
#   'runtimeMinutes': 106,
#   'numVotes': 179934,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1502712',
#   'title': 'Fantastic Four',
#   'startYear': 2015,
#   'runtimeMinutes': 100,
#   'numVotes': 184987,
#   'countryOfOrigin': 'US,DE,GB,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt1517451',
#   'title': 'A Star Is Born',
#   'startYear': 2018,
#   'runtimeMinutes': 136,
#   'numVotes': 438260,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15242330',
#   'title': 'The First Slam Dunk',
#   'startYear': 2022,
#   'runtimeMinutes': 124,
#   'numVotes': 11705,
#   'countryOfOrigin': 'JP',
#   'awardsOrNominations': True},
#  {'id': 'tt1517268',
#   'title': 'Barbie',
#   'startYear': 2023,
#   'runtimeMinutes': 114,
#   'numVotes': 616805,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1524930',
#   'title': 'Vacation',
#   'startYear': 2015,
#   'runtimeMinutes': 99,
#   'numVotes': 127895,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15325794',
#   'title': 'Fall',
#   'startYear': 2022,
#   'runtimeMinutes': 107,
#   'numVotes': 125559,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt15339456',
#   'title': 'Marcel the Shell with Shoes On',
#   'startYear': 2021,
#   'runtimeMinutes': 90,
#   'numVotes': 32045,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15339570',
#   'title': 'Champions',
#   'startYear': 2023,
#   'runtimeMinutes': 124,
#   'numVotes': 33804,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1528100',
#   'title': 'Exodus: Gods and Kings',
#   'startYear': 2014,
#   'runtimeMinutes': 150,
#   'numVotes': 183962,
#   'countryOfOrigin': 'GB,ES,US',
#   'awardsOrNominations': True},
#  {'id': 'tt15255876',
#   'title': 'Emily the Criminal',
#   'startYear': 2022,
#   'runtimeMinutes': 97,
#   'numVotes': 64516,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15314262',
#   'title': 'The Beekeeper',
#   'startYear': 2024,
#   'runtimeMinutes': 105,
#   'numVotes': 164222,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1528854',
#   'title': "Daddy's Home",
#   'startYear': 2015,
#   'runtimeMinutes': 96,
#   'numVotes': 135382,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15474916',
#   'title': 'Smile',
#   'startYear': 2022,
#   'runtimeMinutes': 115,
#   'numVotes': 220367,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15428940',
#   'title': 'Jules',
#   'startYear': 2023,
#   'runtimeMinutes': 87,
#   'numVotes': 16355,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15398776',
#   'title': 'Oppenheimer',
#   'startYear': 2023,
#   'runtimeMinutes': 180,
#   'numVotes': 914191,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt1563742',
#   'title': 'Overboard',
#   'startYear': 2018,
#   'runtimeMinutes': 112,
#   'numVotes': 43077,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15671028',
#   'title': 'No Hard Feelings',
#   'startYear': 2023,
#   'runtimeMinutes': 103,
#   'numVotes': 202118,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1560220',
#   'title': 'Zombieland: Double Tap',
#   'startYear': 2019,
#   'runtimeMinutes': 99,
#   'numVotes': 217393,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15574270',
#   'title': 'I Saw the TV Glow',
#   'startYear': 2024,
#   'runtimeMinutes': 100,
#   'numVotes': 39027,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt15791034',
#   'title': 'Barbarian',
#   'startYear': 2022,
#   'runtimeMinutes': 102,
#   'numVotes': 227362,
#   'countryOfOrigin': 'BG,US',
#   'awardsOrNominations': True},
#  {'id': 'tt15488088',
#   'title': 'Moving On',
#   'startYear': 2022,
#   'runtimeMinutes': 85,
#   'numVotes': 4232,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1571249',
#   'title': 'The Skeleton Twins',
#   'startYear': 2014,
#   'runtimeMinutes': 93,
#   'numVotes': 46101,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt15837338',
#   'title': 'PAW Patrol: The Mighty Movie',
#   'startYear': 2023,
#   'runtimeMinutes': 88,
#   'numVotes': 6079,
#   'countryOfOrigin': 'CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt1587310',
#   'title': 'Maleficent',
#   'startYear': 2014,
#   'runtimeMinutes': 97,
#   'numVotes': 415771,
#   'countryOfOrigin': 'US,CA,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt15789038',
#   'title': 'Elemental',
#   'startYear': 2023,
#   'runtimeMinutes': 101,
#   'numVotes': 153238,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1609486',
#   'title': 'Harold and the Purple Crayon',
#   'startYear': 2024,
#   'runtimeMinutes': 90,
#   'numVotes': 9011,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt1615160',
#   'title': 'The Foreigner',
#   'startYear': 2017,
#   'runtimeMinutes': 113,
#   'numVotes': 128995,
#   'countryOfOrigin': 'GB,CN,US,IN,CH',
#   'awardsOrNominations': True},
#  {'id': 'tt1594972',
#   'title': 'Norm of the North',
#   'startYear': 2016,
#   'runtimeMinutes': 90,
#   'numVotes': 10469,
#   'countryOfOrigin': 'US,IN,IE,CN',
#   'awardsOrNominations': False},
#  {'id': 'tt1590193',
#   'title': 'The Commuter',
#   'startYear': 2018,
#   'runtimeMinutes': 104,
#   'numVotes': 130037,
#   'countryOfOrigin': 'US,GB,FR,CN,CA,ES',
#   'awardsOrNominations': True},
#  {'id': 'tt1619029',
#   'title': 'Jackie',
#   'startYear': 2016,
#   'runtimeMinutes': 100,
#   'numVotes': 85741,
#   'countryOfOrigin': 'US,FR,CL,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt1617661',
#   'title': 'Jupiter Ascending',
#   'startYear': 2015,
#   'runtimeMinutes': 127,
#   'numVotes': 199056,
#   'countryOfOrigin': 'US,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt1596345',
#   'title': 'Pawn Sacrifice',
# ...
#   'startYear': 2018,
#   'runtimeMinutes': 112,
#   'numVotes': 197295,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt5952594',
#   'title': 'The Mustang',
#   'startYear': 2019,
#   'runtimeMinutes': 96,
#   'numVotes': 15030,
#   'countryOfOrigin': 'FR,BE,US',
#   'awardsOrNominations': True},
#  {'id': 'tt5822564',
#   'title': 'The Kitchen',
#   'startYear': 2019,
#   'runtimeMinutes': 102,
#   'numVotes': 23676,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt5827916',
#   'title': 'A Hidden Life',
#   'startYear': 2019,
#   'runtimeMinutes': 174,
#   'numVotes': 30704,
#   'countryOfOrigin': 'GB,DE,US',
#   'awardsOrNominations': True},
#  {'id': 'tt5962210',
#   'title': 'Ingrid Goes West',
#   'startYear': 2017,
#   'runtimeMinutes': 98,
#   'numVotes': 50434,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt5929750',
#   'title': 'Beatriz at Dinner',
#   'startYear': 2017,
#   'runtimeMinutes': 82,
#   'numVotes': 11156,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt5886046',
#   'title': 'Escape Room',
#   'startYear': 2019,
#   'runtimeMinutes': 99,
#   'numVotes': 152613,
#   'countryOfOrigin': 'US,ZA',
#   'awardsOrNominations': True},
#  {'id': 'tt5971474',
#   'title': 'The Little Mermaid',
#   'startYear': 2023,
#   'runtimeMinutes': 135,
#   'numVotes': 173769,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6063050',
#   'title': 'Acrimony',
#   'startYear': 2018,
#   'runtimeMinutes': 120,
#   'numVotes': 10595,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6003368',
#   'title': 'Diary of a Wimpy Kid: The Long Haul',
#   'startYear': 2017,
#   'runtimeMinutes': 91,
#   'numVotes': 12030,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6000478',
#   'title': 'Roman J. Israel, Esq.',
#   'startYear': 2017,
#   'runtimeMinutes': 122,
#   'numVotes': 46154,
#   'countryOfOrigin': 'CA,AE,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6095472',
#   'title': 'The Angry Birds Movie 2',
#   'startYear': 2019,
#   'runtimeMinutes': 97,
#   'numVotes': 39507,
#   'countryOfOrigin': 'FI,US,AU,CA,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt6108178',
#   'title': 'Disobedience',
#   'startYear': 2017,
#   'runtimeMinutes': 114,
#   'numVotes': 38865,
#   'countryOfOrigin': 'IE,GB,US,BE',
#   'awardsOrNominations': True},
#  {'id': 'tt6105098',
#   'title': 'The Lion King',
#   'startYear': 2019,
#   'runtimeMinutes': 118,
#   'numVotes': 284959,
#   'countryOfOrigin': 'US,GB,KE',
#   'awardsOrNominations': True},
#  {'id': 'tt6054650',
#   'title': 'A Question of Faith',
#   'startYear': 2017,
#   'runtimeMinutes': 104,
#   'numVotes': 1241,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt6053438',
#   'title': 'First Reformed',
#   'startYear': 2017,
#   'runtimeMinutes': 113,
#   'numVotes': 65687,
#   'countryOfOrigin': 'US,GB,AU',
#   'awardsOrNominations': True},
#  {'id': 'tt6107548',
#   'title': 'Late Night',
#   'startYear': 2019,
#   'runtimeMinutes': 102,
#   'numVotes': 42712,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6113488',
#   'title': 'The Case for Christ',
#   'startYear': 2017,
#   'runtimeMinutes': 112,
#   'numVotes': 11238,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6182908',
#   'title': 'Smallfoot',
#   'startYear': 2018,
#   'runtimeMinutes': 96,
#   'numVotes': 44534,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6146586',
#   'title': 'John Wick: Chapter 3 - Parabellum',
#   'startYear': 2019,
#   'runtimeMinutes': 130,
#   'numVotes': 460387,
#   'countryOfOrigin': 'US,MA,UA,IT',
#   'awardsOrNominations': True},
#  {'id': 'tt6166392',
#   'title': 'Wonka',
#   'startYear': 2023,
#   'runtimeMinutes': 116,
#   'numVotes': 179658,
#   'countryOfOrigin': 'US,GB,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt6139732',
#   'title': 'Aladdin',
#   'startYear': 2019,
#   'runtimeMinutes': 128,
#   'numVotes': 305792,
#   'countryOfOrigin': 'US,GB,SG,CA,CZ,RS,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt6133466',
#   'title': 'The First Purge',
#   'startYear': 2018,
#   'runtimeMinutes': 97,
#   'numVotes': 75864,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6217804',
#   'title': 'Boo 2! A Madea Halloween',
#   'startYear': 2017,
#   'runtimeMinutes': 101,
#   'numVotes': 5570,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6246322',
#   'title': "Don't Breathe 2",
#   'startYear': 2021,
#   'runtimeMinutes': 98,
#   'numVotes': 78535,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6225520',
#   'title': 'The Man Who Invented Christmas',
#   'startYear': 2017,
#   'runtimeMinutes': 104,
#   'numVotes': 20774,
#   'countryOfOrigin': 'IE,CA,US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt6189022',
#   'title': 'Angel Has Fallen',
#   'startYear': 2019,
#   'runtimeMinutes': 121,
#   'numVotes': 118321,
#   'countryOfOrigin': 'US,GB,PT,CA,BG',
#   'awardsOrNominations': True},
#  {'id': 'tt6263850',
#   'title': 'Deadpool & Wolverine',
#   'startYear': 2024,
#   'runtimeMinutes': 128,
#   'numVotes': 514074,
#   'countryOfOrigin': 'US,GB,NZ,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt6266538',
#   'title': 'Vice',
#   'startYear': 2018,
#   'runtimeMinutes': 132,
#   'numVotes': 170324,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6264654',
#   'title': 'Free Guy',
#   'startYear': 2021,
#   'runtimeMinutes': 115,
#   'numVotes': 468332,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt6320628',
#   'title': 'Spider-Man: Far from Home',
#   'startYear': 2019,
#   'runtimeMinutes': 129,
#   'numVotes': 605789,
#   'countryOfOrigin': 'US,CZ,AU,CA,IT',
#   'awardsOrNominations': True},
#  {'id': 'tt6343314',
#   'title': 'Creed II',
#   'startYear': 2018,
#   'runtimeMinutes': 130,
#   'numVotes': 164028,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6324278',
#   'title': 'Abominable',
#   'startYear': 2019,
#   'runtimeMinutes': 97,
#   'numVotes': 45317,
#   'countryOfOrigin': 'CN,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6394270',
#   'title': 'Bombshell',
#   'startYear': 2019,
#   'runtimeMinutes': 109,
#   'numVotes': 132742,
#   'countryOfOrigin': 'CA,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6306064',
#   'title': 'Adrift',
#   'startYear': 2018,
#   'runtimeMinutes': 96,
#   'numVotes': 64501,
#   'countryOfOrigin': 'HK,IS,US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt6294822',
#   'title': 'The Post',
#   'startYear': 2017,
#   'runtimeMinutes': 116,
#   'numVotes': 168478,
#   'countryOfOrigin': 'US,IN',
#   'awardsOrNominations': True},
#  {'id': 'tt6359956',
#   'title': 'A Bad Moms Christmas',
#   'startYear': 2017,
#   'runtimeMinutes': 104,
#   'numVotes': 60805,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt6348138',
#   'title': 'Missing Link',
#   'startYear': 2019,
#   'runtimeMinutes': 93,
#   'numVotes': 30007,
#   'countryOfOrigin': 'US,CA,NL,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt6443346',
#   'title': 'Black Adam',
#   'startYear': 2022,
#   'runtimeMinutes': 125,
#   'numVotes': 295493,
#   'countryOfOrigin': 'US,CA,NZ,HU',
#   'awardsOrNominations': True},
#  {'id': 'tt6450186',
#   'title': 'I Can Only Imagine',
#   'startYear': 2018,
#   'runtimeMinutes': 110,
#   'numVotes': 19685,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6450804',
#   'title': 'Terminator: Dark Fate',
#   'startYear': 2019,
#   'runtimeMinutes': 128,
#   'numVotes': 206226,
#   'countryOfOrigin': 'US,ES,HU,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt6398184',
#   'title': 'Downton Abbey',
#   'startYear': 2019,
#   'runtimeMinutes': 122,
#   'numVotes': 67437,
#   'countryOfOrigin': 'GB,CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6428676',
#   'title': 'Wonder Park',
#   'startYear': 2019,
#   'runtimeMinutes': 85,
#   'numVotes': 13194,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6421110',
#   'title': 'Proud Mary',
#   'startYear': 2018,
#   'runtimeMinutes': 89,
#   'numVotes': 11305,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6472976',
#   'title': 'Five Feet Apart',
#   'startYear': 2019,
#   'runtimeMinutes': 116,
#   'numVotes': 92204,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6475714',
#   'title': 'Monster Hunter',
#   'startYear': 2020,
#   'runtimeMinutes': 103,
#   'numVotes': 72560,
#   'countryOfOrigin': 'DE,US,JP,CN,ZA,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt6439020',
#   'title': 'The Personal History of David Copperfield',
#   'startYear': 2019,
#   'runtimeMinutes': 119,
#   'numVotes': 23476,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6467266',
#   'title': 'Sing 2',
#   'startYear': 2021,
#   'runtimeMinutes': 110,
#   'numVotes': 96618,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6565702',
#   'title': 'X-Men: Dark Phoenix',
#   'startYear': 2019,
#   'runtimeMinutes': 113,
#   'numVotes': 220264,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6495056',
#   'title': 'Migration',
#   'startYear': 2023,
#   'runtimeMinutes': 83,
#   'numVotes': 41493,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6512428',
#   'title': 'Indivisible',
#   'startYear': 2018,
#   'runtimeMinutes': 119,
#   'numVotes': 1454,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6513120',
#   'title': 'Fighting with My Family',
#   'startYear': 2019,
#   'runtimeMinutes': 108,
#   'numVotes': 91470,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6543652',
#   'title': 'Cold War',
#   'startYear': 2018,
#   'runtimeMinutes': 89,
#   'numVotes': 64160,
#   'countryOfOrigin': 'PL,GB,FR,BE,IN',
#   'awardsOrNominations': True},
#  {'id': 'tt6652708',
#   'title': "God's Not Dead: A Light in Darkness",
#   'startYear': 2018,
#   'runtimeMinutes': 105,
#   'numVotes': 4922,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6663582',
#   'title': 'The Spy Who Dumped Me',
#   'startYear': 2018,
#   'runtimeMinutes': 117,
#   'numVotes': 85512,
#   'countryOfOrigin': 'US,CA,DE,HU,NL',
#   'awardsOrNominations': True},
#  {'id': 'tt6644200',
#   'title': 'A Quiet Place',
#   'startYear': 2018,
#   'runtimeMinutes': 90,
#   'numVotes': 634356,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6574272',
#   'title': 'Phoenix Forgotten',
#   'startYear': 2017,
#   'runtimeMinutes': 87,
#   'numVotes': 7428,
#   'countryOfOrigin': 'US,CN,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt6587046',
#   'title': 'The Boy and the Heron',
#   'startYear': 2023,
#   'runtimeMinutes': 124,
#   'numVotes': 99223,
#   'countryOfOrigin': 'JP',
#   'awardsOrNominations': True},
#  {'id': 'tt6673612',
#   'title': 'Dolittle',
#   'startYear': 2020,
#   'runtimeMinutes': 101,
#   'numVotes': 74965,
#   'countryOfOrigin': 'CN,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6723592',
#   'title': 'Tenet',
#   'startYear': 2020,
#   'runtimeMinutes': 150,
#   'numVotes': 636561,
#   'countryOfOrigin': 'US,GB',
#   'awardsOrNominations': True},
#  {'id': 'tt6751668',
#   'title': 'Parasite',
#   'startYear': 2019,
#   'runtimeMinutes': 132,
#   'numVotes': 1081584,
#   'countryOfOrigin': 'KR',
#   'awardsOrNominations': True},
#  {'id': 'tt6722030',
#   'title': 'The Intruder',
#   'startYear': 2019,
#   'runtimeMinutes': 102,
#   'numVotes': 20808,
#   'countryOfOrigin': 'US,CA',
#   'awardsOrNominations': False},
#  {'id': 'tt6718170',
#   'title': 'The Super Mario Bros. Movie',
#   'startYear': 2023,
#   'runtimeMinutes': 92,
#   'numVotes': 273702,
#   'countryOfOrigin': 'JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6710474',
#   'title': 'Everything Everywhere All at Once',
#   'startYear': 2022,
#   'runtimeMinutes': 139,
#   'numVotes': 586898,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6791096',
#   'title': 'I Feel Pretty',
#   'startYear': 2018,
#   'runtimeMinutes': 110,
#   'numVotes': 59184,
#   'countryOfOrigin': 'CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6781982',
#   'title': 'Night School',
#   'startYear': 2018,
#   'runtimeMinutes': 111,
#   'numVotes': 47952,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt6772950',
#   'title': 'Truth or Dare',
#   'startYear': 2018,
#   'runtimeMinutes': 100,
#   'numVotes': 70982,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6791350',
#   'title': 'Guardians of the Galaxy Vol. 3',
#   'startYear': 2023,
#   'runtimeMinutes': 150,
#   'numVotes': 438303,
#   'countryOfOrigin': 'US,NZ,FR,CA',
#   'awardsOrNominations': True},
#  {'id': 'tt6820256',
#   'title': 'Arctic',
#   'startYear': 2018,
#   'runtimeMinutes': 98,
#   'numVotes': 61208,
#   'countryOfOrigin': 'US,IS',
#   'awardsOrNominations': True},
#  {'id': 'tt6850820',
#   'title': 'Peppermint',
#   'startYear': 2018,
#   'runtimeMinutes': 101,
#   'numVotes': 73993,
#   'countryOfOrigin': 'US,CN',
#   'awardsOrNominations': True},
#  {'id': 'tt6811018',
#   'title': 'The Kid Who Would Be King',
#   'startYear': 2019,
#   'runtimeMinutes': 120,
#   'numVotes': 19820,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6806448',
#   'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'startYear': 2019,
#   'runtimeMinutes': 137,
#   'numVotes': 250178,
#   'countryOfOrigin': 'US,JP',
#   'awardsOrNominations': True},
#  {'id': 'tt6802308',
#   'title': 'The 15:17 to Paris',
#   'startYear': 2018,
#   'runtimeMinutes': 94,
#   'numVotes': 36616,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6878306',
#   'title': 'News of the World',
#   'startYear': 2020,
#   'runtimeMinutes': 118,
#   'numVotes': 99149,
#   'countryOfOrigin': 'CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6823368',
#   'title': 'Glass',
#   'startYear': 2019,
#   'runtimeMinutes': 129,
#   'numVotes': 295109,
#   'countryOfOrigin': 'CN,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6857166',
#   'title': 'Book Club',
#   'startYear': 2018,
#   'runtimeMinutes': 104,
#   'numVotes': 34054,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6857112',
#   'title': 'Us',
#   'startYear': 2019,
#   'runtimeMinutes': 116,
#   'numVotes': 372024,
#   'countryOfOrigin': 'CN,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6856242',
#   'title': "The King's Man",
#   'startYear': 2021,
#   'runtimeMinutes': 131,
#   'numVotes': 188918,
#   'countryOfOrigin': 'GB,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6902332',
#   'title': 'The Marksman',
#   'startYear': 2021,
#   'runtimeMinutes': 108,
#   'numVotes': 46587,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': False},
#  {'id': 'tt6881490',
#   'title': 'Sound of Hope: The Story of Possum Trot',
#   'startYear': 2024,
#   'runtimeMinutes': 130,
#   'numVotes': 2247,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6911608',
#   'title': 'Mamma Mia! Here We Go Again',
#   'startYear': 2018,
#   'runtimeMinutes': 114,
#   'numVotes': 116597,
#   'countryOfOrigin': 'GB,CN,HR,JP,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6906292',
#   'title': 'Retribution',
#   'startYear': 2023,
#   'runtimeMinutes': 91,
#   'numVotes': 26085,
#   'countryOfOrigin': 'FR,DE,ES,US,CA,IE',
#   'awardsOrNominations': True},
#  {'id': 'tt6924650',
#   'title': 'Midway',
#   'startYear': 2019,
#   'runtimeMinutes': 138,
#   'numVotes': 101533,
#   'countryOfOrigin': 'US,CA,CN,HK',
#   'awardsOrNominations': True},
#  {'id': 'tt6920084',
#   'title': 'Resident Evil: Welcome to Raccoon City',
#   'startYear': 2021,
#   'runtimeMinutes': 107,
#   'numVotes': 69067,
#   'countryOfOrigin': 'CA,DE',
#   'awardsOrNominations': True},
#  {'id': 'tt6902696',
#   'title': 'Gloria Bell',
#   'startYear': 2018,
#   'runtimeMinutes': 102,
#   'numVotes': 13628,
#   'countryOfOrigin': 'CL,US',
#   'awardsOrNominations': True},
#  {'id': 'tt6932874',
#   'title': 'The Boss Baby: Family Business',
#   'startYear': 2021,
#   'runtimeMinutes': 107,
#   'numVotes': 24932,
#   'countryOfOrigin': 'US',
#   'awardsOrNominations': True},
#  {'id': 'tt6964076',
#   'title': 'Pavarotti',
#   'startYear': 2019,
#   'runtimeMinutes': 114,
#   'numVotes': 4021,
#   'countryOfOrigin': 'US,GB,FR,IT',
#   'awardsOrNominations': True},
#  {'id': 'tt6951892',
#   'title': 'Samson',
#   'startYear': 2018,
#   'runtimeMinutes': 110,
#   'numVotes': 5145,
#   'countryOfOrigin': 'ZA,US',
#   'awardsOrNominations': False},
#  ...]

# %%
with open(results_dir / 'ts_additional_feats.csv', 'w') as outfile:
    writer = csv.DictWriter(outfile, fieldnames=movies[0].keys())
    writer.writerows(movies)
