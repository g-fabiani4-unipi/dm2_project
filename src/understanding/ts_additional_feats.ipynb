# %% [markdown]
# We use the imdb api (see [documentation](https://imdbapi.dev/)) in order to retrieve some basic informations about the titles represented in the time series dataset.

# %%
import requests
import csv
from pathlib import Path
from itertools import batched
from tqdm import tqdm
import pandas as pd

# %%
data_dir = Path("../../data")
results_dir = Path("../../results")
data_path = data_dir / 'imdb_ts.csv'

# %%
base_url = 'https://api.imdbapi.dev/'
endpoint = "titles/"

# %%
title_id = 'tt0062622'

# %% [markdown]
# ## Example with one record

# %%
response = requests.get(base_url + endpoint + title_id)
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'id': 'tt0062622',
#  'type': 'movie',
#  'primaryTitle': '2001: A Space Odyssey',
#  'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNjU0NDFkMTQtZWY5OS00MmZhLTg3Y2QtZmJhMzMzMWYyYjc2XkEyXkFqcGc@._V1_.jpg',
#   'width': 1380,
#   'height': 2044},
#  'startYear': 1968,
#  'runtimeSeconds': 8940,
#  'genres': ['Adventure', 'Sci-Fi'],
#  'rating': {'aggregateRating': 8.3, 'voteCount': 761423},
#  'metacritic': {'score': 84, 'reviewCount': 25},
#  'plot': 'When a mysterious artifact is uncovered on the Moon, a spacecraft manned by two humans and one supercomputer is sent to Jupiter to find its origins.',
#  'directors': [{'id': 'nm0000040',
#    'displayName': 'Stanley Kubrick',
#    'alternativeNames': ['Stanley Kubric'],
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#     'width': 3121,
#     'height': 4020},
#    'primaryProfessions': ['writer', 'director', 'producer']}],
#  'writers': [{'id': 'nm0000040',
#    'displayName': 'Stanley Kubrick',
#    'alternativeNames': ['Stanley Kubric'],
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#     'width': 3121,
#     'height': 4020},
#    'primaryProfessions': ['writer', 'director', 'producer']},
#   {'id': 'nm0002009',
#    'displayName': 'Arthur C. Clarke',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#     'width': 1200,
#     'height': 1270}}],
#  'stars': [{'id': 'nm0001158',
#    'displayName': 'Keir Dullea',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMzFjZmUwNTgtYWQwYy00ZTUzLWE4MTEtZTQ1ZDVmZDNhZmFkXkEyXkFqcGc@._V1_.jpg',
#     'width': 2844,
#     'height': 3859}},
#   {'id': 'nm0516972',
#    'displayName': 'Gary Lockwood',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOTdmYzY4MDItNjM5OS00NTJlLWJkMjktZTYwYzBhMTU0ZWFmXkEyXkFqcGc@._V1_.jpg',
#     'width': 2500,
#     'height': 1875}},
#   {'id': 'nm0843213',
#    'displayName': 'William Sylvester',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOGI5YzExYjctM2M1My00OTlkLThjODYtMTE2OGExZmE1NDZmXkEyXkFqcGc@._V1_.jpg',
#     'width': 1920,
#     'height': 864}},
#   {'id': 'nm0725220',
#    'displayName': 'Daniel Richter',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMGJlZTg1MTAtNDgzOS00NTdkLTliY2UtY2ZjZGYyMDU5ZmI0XkEyXkFqcGc@._V1_.jpg',
#     'width': 2884,
#     'height': 2000}}],
#  'originCountries': [{'code': 'GB', 'name': 'United Kingdom'},
#   {'code': 'US', 'name': 'United States'}],
#  'spokenLanguages': [{'code': 'eng', 'name': 'English'},
#   {'code': 'rus', 'name': 'Russian'},
#   {'code': 'fra', 'name': 'French'}]}

# %%
movie = dict(
    id=title_id,
    title=data.get('primaryTitle'),
    startYear=data.get('startYear'),
    runtimeMinutes=round(data.get('runtimeSeconds') / 60),
    numVotes=data.get('rating', {}).get('voteCount'),
    countryOfOrigin=','.join(country.get('code', '') for country in data.get('originCountries', []))
)

# %%
movie
# Out:
# {'id': 'tt0062622',
#  'title': '2001: A Space Odyssey',
#  'startYear': 1968,
#  'runtimeMinutes': 149,
#  'numVotes': 761423,
#  'countryOfOrigin': 'GB,US'}

# %% [markdown]
# It is also possible to get multiple (up to 5) records at the same time.

# %%
ids = ['tt0062622','tt0064816']
response = requests.get(base_url + 'titles:batchGet?titleIds=' + '&titleIds='.join(ids))

# %%
response.status_code
response.json()
# Out:
# {'titles': [{'id': 'tt0062622',
#    'type': 'movie',
#    'primaryTitle': '2001: A Space Odyssey',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNjU0NDFkMTQtZWY5OS00MmZhLTg3Y2QtZmJhMzMzMWYyYjc2XkEyXkFqcGc@._V1_.jpg',
#     'width': 1380,
#     'height': 2044},
#    'startYear': 1968,
#    'runtimeSeconds': 8940,
#    'genres': ['Adventure', 'Sci-Fi'],
#    'rating': {'aggregateRating': 8.3, 'voteCount': 761423},
#    'metacritic': {'score': 84, 'reviewCount': 25},
#    'plot': 'When a mysterious artifact is uncovered on the Moon, a spacecraft manned by two humans and one supercomputer is sent to Jupiter to find its origins.',
#    'directors': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']}],
#    'writers': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']},
#     {'id': 'nm0002009',
#      'displayName': 'Arthur C. Clarke',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#       'width': 1200,
#       'height': 1270}}],
#    'stars': [{'id': 'nm0001158',
#      'displayName': 'Keir Dullea',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMzFjZmUwNTgtYWQwYy00ZTUzLWE4MTEtZTQ1ZDVmZDNhZmFkXkEyXkFqcGc@._V1_.jpg',
#       'width': 2844,
#       'height': 3859}},
#     {'id': 'nm0516972',
#      'displayName': 'Gary Lockwood',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOTdmYzY4MDItNjM5OS00NTJlLWJkMjktZTYwYzBhMTU0ZWFmXkEyXkFqcGc@._V1_.jpg',
#       'width': 2500,
#       'height': 1875}},
#     {'id': 'nm0843213',
#      'displayName': 'William Sylvester',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOGI5YzExYjctM2M1My00OTlkLThjODYtMTE2OGExZmE1NDZmXkEyXkFqcGc@._V1_.jpg',
#       'width': 1920,
#       'height': 864}},
#     {'id': 'nm0725220',
#      'displayName': 'Daniel Richter',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMGJlZTg1MTAtNDgzOS00NTdkLTliY2UtY2ZjZGYyMDU5ZmI0XkEyXkFqcGc@._V1_.jpg',
#       'width': 2884,
#       'height': 2000}}],
#    'originCountries': [{'code': 'GB', 'name': 'United Kingdom'},
#     {'code': 'US', 'name': 'United States'}],
#    'spokenLanguages': [{'code': 'eng', 'name': 'English'},
#     {'code': 'rus', 'name': 'Russian'},
#     {'code': 'fra', 'name': 'French'}]},
#   {'id': 'tt0064816',
#    'type': 'movie',
#    'primaryTitle': 'The Swimming Pool',
#    'originalTitle': 'La piscine',
#    'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZDliNGUyYTMtZWM5OS00ZmQ1LTg5NGItM2I4YTg0N2E0YWQwXkEyXkFqcGc@._V1_.jpg',
#     'width': 1400,
#     'height': 2125},
#    'startYear': 1969,
#    'runtimeSeconds': 7320,
#    'genres': ['Crime', 'Drama', 'Romance'],
#    'rating': {'aggregateRating': 7.1, 'voteCount': 15502},
#    'metacritic': {'score': 76, 'reviewCount': 9},
#    'plot': 'Jean-Paul and Marianne spend lazy holidays at their villa in idyllic Southern France. However when Harry and his attractive young daughter Penelope show up, the dreamy summer days are suddenly filled with unspoken tension and jealousy.',
#    'directors': [{'id': 'nm0220227',
#      'displayName': 'Jacques Deray',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMzU2MGJiOTQtNjQ1Mi00ZTE3LTg0NDctM2FhYzBkNDA4ZmM0XkEyXkFqcGc@._V1_.jpg',
#       'width': 512,
#       'height': 638}}],
#    'writers': [{'id': 'nm0656098', 'displayName': 'Alain Page'},
#     {'id': 'nm0140643',
#      'displayName': 'Jean-Claude Carrière',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNzM3NzcxMDkwOF5BMl5BanBnXkFtZTcwMzE3MDQwOA@@._V1_.jpg',
#       'width': 1365,
#       'height': 2048}},
#     {'id': 'nm0220227',
#      'displayName': 'Jacques Deray',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMzU2MGJiOTQtNjQ1Mi00ZTE3LTg0NDctM2FhYzBkNDA4ZmM0XkEyXkFqcGc@._V1_.jpg',
#       'width': 512,
#       'height': 638}}],
#    'stars': [{'id': 'nm0001128',
#      'displayName': 'Alain Delon',
#      'alternativeNames': ['A. Delon'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMTI0MDI2MDY3OV5BMl5BanBnXkFtZTYwNDg5ODM0._V1_.jpg',
#       'width': 259,
#       'height': 400},
#      'primaryProfessions': ['actor', 'producer', 'writer']},
#     {'id': 'nm0002769',
#      'displayName': 'Romy Schneider',
#      'alternativeNames': ['Romy Albach-Retty',
#       'Rosemarie Magdalena Schneider',
#       'Romy Schneider-Albach'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMTg4NDI2NzA3OF5BMl5BanBnXkFtZTcwNDM1OTQyOA@@._V1_.jpg',
#       'width': 1638,
#       'height': 2048},
#      'primaryProfessions': ['actress', 'soundtrack']},
#     {'id': 'nm0000945',
#      'displayName': 'Jane Birkin',
#      'alternativeNames': ['Jane B.', 'Mademoiselle Birkin', 'Jane Bírkín'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMTQ4MDM3NjczOV5BMl5BanBnXkFtZTcwNTQ0MDgwNA@@._V1_.jpg',
#       'width': 266,
#       'height': 400},
#      'primaryProfessions': ['actress', 'director', 'writer']},
#     {'id': 'nm0740067',
#      'displayName': 'Maurice Ronet',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMTU0MTA3MTQxMF5BMl5BanBnXkFtZTgwNjQ2MTg3NTE@._V1_.jpg',
#       'width': 1333,
#       'height': 2011}}],
#    'originCountries': [{'code': 'FR', 'name': 'France'},
#     {'code': 'IT', 'name': 'Italy'}],
#    'spokenLanguages': [{'code': 'fra', 'name': 'French'},
#     {'code': 'eng', 'name': 'English'}]}]}

# %% [markdown]
# Also we query for informations relative to awards and nominations. In this case we only check if the json of the response has some content in order to determine if the title was awarded nominations or awards.
#
# Since almost all records have awards or nominations, we get also the counts.

# %%
response = requests.get(base_url + endpoint + title_id + '/awardNominations')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'stats': {'nominationCount': 14, 'winCount': 18},
#  'awardNominations': [{'nominees': [{'id': 'nm0706937',
#      'displayName': 'Douglas Rain',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BOGRlNDUxNDAtY2YwMS00N2YyLTk4OGEtZGZjZDJjMzg3Y2NhXkEyXkFqcGc@._V1_.jpg',
#       'width': 658,
#       'height': 819}}],
#    'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 2024,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Character',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2024,
#    'text': 'Saturn Award',
#    'category': 'Best Film Home Media Collection Release'},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']}],
#    'event': {'id': 'ev0001001', 'name': 'Kinema Junpo Awards'},
#    'year': 1969,
#    'text': 'Kinema Junpo Award',
#    'category': 'Best Foreign Language Film'},
#   {'nominees': [{'id': 'nm0006154', 'displayName': 'Aram Khachaturyan'},
#     {'id': 'nm0006309',
#      'displayName': 'Richard Strauss',
#      'alternativeNames': ['R. Shtraus',
#       'R. Strauss',
#       'Richard Morten Strauss'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BM2IxY2NhMzAtYWM2YS00Y2MzLTk3NzEtYWY1NGZkZTliNTMzXkEyXkFqcGc@._V1_.jpg',
#       'width': 1152,
#       'height': 1709},
#      'primaryProfessions': ['music_department', 'writer', 'composer']},
#     {'id': 'nm0006310',
#      'displayName': 'Johann Strauss',
#      'alternativeNames': ['Johann Strauß der Jüngere',
#       'Iogann Shtraus',
#       'Johann Strauss Sohn',
#       'Johann Strauß Sohn',
#       'Johann Strauss Son',
#       'Johann Strauss II',
#       'Johan Strauss II',
#       'Johan Strauss',
#       'Strauss',
#       'Johann Strauß Jr.',
#       'Johann Strauß',
#       'Johann Strauss figlio',
#       'Johann Strauss the son'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMjJiMjBkYjUtNTAyOC00N2ZjLWIyODEtYzA2ZTgwNDAxZWJmXkEyXkFqcGc@._V1_.jpg',
#       'width': 851,
#       'height': 1200},
#      'primaryProfessions': ['music_department', 'composer', 'writer']},
#     {'id': 'nm0509893', 'displayName': 'György Ligeti'}],
#    'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 2022,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Score',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']},
#     {'id': 'nm0002009',
#      'displayName': 'Arthur C. Clarke',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#       'width': 1200,
#       'height': 1270}}],
#    'event': {'id': 'ev0000712', 'name': "Writers' Guild of Great Britain"},
#    'year': 1969,
#    'text': "Writers' Guild of Great Britain Award",
#    'category': 'Best British Original Screenplay'},
#   {'event': {'id': 'ev0002419',
#     'name': 'Turkish Film Critics Association (SIYAD) Awards'},
#    'year': 1974,
#    'text': 'SIYAD Award',
#    'category': 'Best Foreign Film'},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2019,
#    'text': 'Saturn Award',
#    'category': 'Best DVD/Blu-Ray Classic Film Release',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']}],
#    'event': {'id': 'ev0002340', 'name': 'Jules Verne Awards'},
#    'year': 2008,
#    'text': 'Jules Verne Légendaire Award',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2015,
#    'text': 'Saturn Award',
#    'category': 'Best DVD/Blu-Ray Collection'},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2008,
#    'text': 'Saturn Award',
#    'category': 'Best DVD Collection'},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']}],
#    'event': {'id': 'ev0000450', 'name': 'Moscow International Film Festival'},
#    'year': 1969,
#    'text': 'Golden Prize',
#    'category': 'Best Feature Film'},
#   {'event': {'id': 'ev0002704',
#     'name': 'Online Film & Television Association'},
#    'year': 1997,
#    'text': 'OFTA Film Hall of Fame',
#    'category': 'Motion Picture',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0005910',
#      'displayName': 'Geoffrey Unsworth',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZTkwNWI5ODAtYmFkYy00NzZkLTkzODUtODQxZGFkNDNkOTFmXkEyXkFqcGc@._V1_.jpg',
#       'width': 444,
#       'height': 480}}],
#    'event': {'id': 'ev0000471',
#     'name': 'National Society of Film Critics Awards, USA'},
#    'year': 1969,
#    'text': 'NSFC Award',
#    'category': 'Best Cinematography',
#    'winnerRank': 3},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']},
#     {'id': 'nm0002009',
#      'displayName': 'Arthur C. Clarke',
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYmYzMzViMmMtNWE5YS00OTVkLWI4OGUtMzViNmRmMjliYTYxXkEyXkFqcGc@._V1_.jpg',
#       'width': 1200,
#       'height': 1270}}],
#    'event': {'id': 'ev0000335', 'name': 'Hugo Awards'},
#    'year': 1969,
#    'text': 'Hugo',
#    'category': 'Best Dramatic Presentation',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000004',
#     'name': 'Academy of Science Fiction, Fantasy & Horror Films, USA'},
#    'year': 2012,
#    'text': 'Saturn Award',
#    'category': 'Best DVD Collection',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000464', 'name': 'National Board of Review, USA'},
#    'year': 1969,
#    'text': 'NBR Award',
#    'category': 'Top Ten Films',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000468',
#     'name': 'National Film Preservation Board, USA'},
#    'year': 1991,
#    'text': 'National Film Registry',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'event': {'id': 'ev0000394', 'name': 'Laurel Awards'},
#    'year': 1968,
#    'text': 'Golden Laurel',
#    'category': 'Road Show',
#    'isWinner': True,
#    'winnerRank': 1},
#   {'nominees': [{'id': 'nm0000040',
#      'displayName': 'Stanley Kubrick',
#      'alternativeNames': ['Stanley Kubric'],
#      'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDZlOGFiZmYtZDRmZi00M2RkLTg1MDgtYjUwYjJiYmNiZjhmXkEyXkFqcGc@._V1_.jpg',
#       'width': 3121,
#       'height': 4020},
#      'primaryProfessions': ['writer', 'director', 'producer']}],
#    'event': {'id': 'ev0000123', 'name': 'BAFTA Awards'},
#    'year': 1969,
#    'text': 'UN Award'},
#   {'nominees': [{'id': 'nm0753160', 'displayName': 'Winston Ryder'}],
#    'event': {'id': 'ev0000123', 'name': 'BAFTA Awards'},
#    'year': 1969,
#    'text': 'BAFTA Film Award',
#    'category': 'Best Sound Track',
#    'isWinner': True,
#    'winnerRank': 1}],
#  'nextPageToken': 'eyJpZCI6ImFuMDE0OTcyNyJ9'}

# %% [markdown]
# ## And now the rest

# %%
title_ids = []

with open(data_path) as infile:
    reader = csv.DictReader(infile)
    for row in reader:
        title_ids.append(row.get('id'))

# %%
len(title_ids)
# Out:
# 1134

# %%
def get_movies_data(title_ids):
    movies = []
    for batch in tqdm(list(batched(title_ids, 5))):
        response = requests.get(base_url + 'titles:batchGet?titleIds=' + '&titleIds='.join(batch))
        if response.ok:
            movies += [dict(
                id=movie.get('id'),
                title=movie.get('primaryTitle'),
                startYear=movie.get('startYear'),
                runtimeMinutes=round(movie.get('runtimeSeconds') / 60 if data.get('runtimeSeconds') else None),
                numVotes=movie.get('rating', {}).get('voteCount'),
                countryOfOrigin=','.join(country.get('code', '') for country in movie.get('originCountries', []))
                ) for movie in response.json().get('titles', [])]
    return movies

# %%
movies = get_movies_data(title_ids)
# Out:
# 100%|██████████| 227/227 [01:01<00:00,  3.70it/s]

# %%
len(movies)
# Out:
# 1134

# %%
def get_awards_info(movies):
    for movie in tqdm(movies):
        response = requests.get(base_url + endpoint + movie['id'] + '/awardNominations')
        if response.ok:
            data = response.json()
            if data:
                movie['awardsOrNominations'] = True
                movie['awards'] = data.get('stats').get('winCount', 0)
                movie['nominations'] = data.get('stats').get('nominationCount', 0)
            else:
                movie['awardsOrNominations'] = False
                movie['awards'] = 0
                movie['nominations'] = 0
        else:
            print(movie['id'], "response status code:", response.status_code)
            print(response.json().get('message'))
    return movies

# %%
movies = get_awards_info(movies)
movies[0]
# Out:
#   6%|▌         | 66/1134 [00:16<05:07,  3.47it/s]
# tt10838180 response status code: 500
# ListTitleImages: failed to sync images from IMDb: SyncTitleAwardNominationsFromIMDb: imdb:FetchTitleAwardNominations: batch fetch names imdb:BatchFetchNames imdb:Execute failed to execute query nameListDetails: response with error: Too many ids. Maximum: 250, was: 301.
#  29%|██▉       | 328/1134 [01:19<03:12,  4.18it/s]
# tt1825683 response status code: 500
# ListTitleImages: failed to sync images from IMDb: SyncTitleAwardNominationsFromIMDb: imdb:FetchTitleAwardNominations imdb:Execute failed to execute query TitleAwardsSubPagePagination: failed to send request: Get "https://caching.graphql.imdb.com/?extensions=%7B%22persistedQuery%22%3A%7B%22sha256Hash%22%3A%228b4946d86888821ee8c8624d40c14e1cb6a0c8bf01179d186359e20bb0945da3%22%2C%22version%22%3A1%7D%7D&operationName=TitleAwardsSubPagePagination&variables=%7B%22after%22%3A%22YW4xMTU0MDIy%22%2C%22const%22%3A%22tt1825683%22%2C%22filter%22%3A%7B%7D%2C%22first%22%3A50%2C%22locale%22%3A%22en_US%22%2C%22originalTitleText%22%3Afalse%7D": context canceled
#  65%|██████▍   | 734/1134 [02:58<01:39,  4.03it/s]
# tt4154796 response status code: 500
# ListTitleImages: failed to sync images from IMDb: SyncTitleAwardNominationsFromIMDb: imdb:FetchTitleAwardNominations imdb:Execute failed to execute query TitleAwardsSubPagePagination: failed to send request: Get "https://caching.graphql.imdb.com/?extensions=%7B%22persistedQuery%22%3A%7B%22sha256Hash%22%3A%228b4946d86888821ee8c8624d40c14e1cb6a0c8bf01179d186359e20bb0945da3%22%2C%22version%22%3A1%7D%7D&operationName=TitleAwardsSubPagePagination&variables=%7B%22after%22%3A%22YW4xMjk5MTk5%22%2C%22const%22%3A%22tt4154796%22%2C%22filter%22%3A%7B%7D%2C%22first%22%3A50%2C%22locale%22%3A%22en_US%22%2C%22originalTitleText%22%3Afalse%7D": context canceled
#  98%|█████████▊| 1109/1134 [04:31<00:06,  3.76it/s]
# tt9114286 response status code: 500
# ListTitleImages: failed to sync images from IMDb: SyncTitleAwardNominationsFromIMDb: imdb:FetchTitleAwardNominations imdb:Execute failed to execute query TitleAwardsSubPagePagination: failed to send request: Get "https://caching.graphql.imdb.com/?extensions=%7B%22persistedQuery%22%3A%7B%22sha256Hash%22%3A%228b4946d86888821ee8c8624d40c14e1cb6a0c8bf01179d186359e20bb0945da3%22%2C%22version%22%3A1%7D%7D&operationName=TitleAwardsSubPagePagination&variables=%7B%22after%22%3A%22YW4xODI4MTEw%22%2C%22const%22%3A%22tt9114286%22%2C%22filter%22%3A%7B%7D%2C%22first%22%3A50%2C%22locale%22%3A%22en_US%22%2C%22originalTitleText%22%3Afalse%7D": context canceled
# 100%|██████████| 1134/1134 [04:37<00:00,  4.08it/s]
# {'id': 'tt0359950',
#  'title': 'The Secret Life of Walter Mitty',
#  'startYear': 2013,
#  'runtimeMinutes': 114,
#  'numVotes': 359965,
#  'countryOfOrigin': 'US,GB',
#  'awardsOrNominations': True,
#  'awards': 5,
#  'nominations': 18}

# %%
movies_df = pd.DataFrame(movies)
movies_df = movies_df.set_index('id')

# %% [markdown]
# Preserve original ordering

# %%
try:
    original_df = pd.read_csv(results_dir / 'ts_additional_feats.csv', index_col='id')
except IOError as e:
    print(e)
else:
    movies_df = movies_df.loc[original_df.index]

# %%
movies_df.to_csv(results_dir / 'ts_additional_feats.csv')
